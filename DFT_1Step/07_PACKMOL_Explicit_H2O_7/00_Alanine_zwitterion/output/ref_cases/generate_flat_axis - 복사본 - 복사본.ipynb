# %%
import numpy as np

def generate_uniform_disk_7(radius=2.0, height=5.4728, axis='z'):
    coords = []
    
    # 중심에 1개
    center = np.array([0.0, 0.0])
    coords.append(center)
    
    # 외곽 6개: 정육각형 대칭
    for i in range(6):
        angle = 2 * np.pi * i / 6
        x = radius * np.cos(angle)
        y = radius * np.sin(angle)
        coords.append(np.array([x, y]))
    
    coords = np.array(coords)
    
    # 3D 변환
    final = []
    for x, y in coords:
        if axis == 'z':
            final.append([x, y, height])
        elif axis == '-z':
            final.append([x, y, -height])
        elif axis == 'x':
            final.append([height, x, y])
        elif axis == '-x':
            final.append([-height, x, y])
        elif axis == 'y':
            final.append([x, height, y])
        elif axis == '-y':
            final.append([x, -height, y])
    return np.array(final)
import matplotlib.pyplot as plt

coords = generate_uniform_disk_7(radius=2.0)
plt.scatter(coords[:, 0], coords[:, 1], s=200, c='skyblue')
for i, (x, y, _) in enumerate(coords):
    plt.text(x, y, str(i), ha='center', va='center')
plt.gca().set_aspect('equal')
plt.title("Uniform 7-particle packing on disk (z-plane)")
plt.show()

# %% [markdown]
# ## 알고리즘: Concentric Ring Layering
# n개의 점을 타원 내부에 배치하되, 그 중 가장 가까운 두 점 사이의 거리를 최대화하라
# ### 실용적 구현 (방법 1): 물리 기반 repulsion + ellipse constraint

# %%
import numpy as np
import os

def pack_points_in_ellipse(n, ry, rz, steps=500, lr=0.01):
    points = []
    while len(points) < n:
        y, z = np.random.uniform(-1, 1, size=2)
        if y**2 + z**2 <= 1.0:
            points.append([y, z])
    points = np.array(points)

    for _ in range(steps):
        grad = np.zeros_like(points)
        for i in range(n):
            for j in range(n):
                if i == j: continue
                diff = points[i] - points[j]
                dist = np.linalg.norm(diff) + 1e-6
                grad[i] += diff / dist**3
        points += lr * grad
        for i in range(n):
            y, z = points[i]
            norm = (y**2 + z**2)
            if norm > 1.0:
                points[i] /= np.sqrt(norm)
    return points[:, 0] * ry, points[:, 1] * rz

def place_on_plane(yz_coords, axis, offset, a, b, c):
    points = []
    for y, z in yz_coords:
        if axis == 'x':
            points.append([offset * a, y, z])
        elif axis == 'y':
            points.append([y, offset * b, z])
        elif axis == 'z':
            points.append([y, z, offset * c])
    return np.array(points)

def write_xyz(filename, water_coords, center_path="../../rotated_00_Alanine_zwitterion.xyz"):
    with open(center_path) as f:
        lines = f.readlines()
    n_center = int(lines[0])
    center_atoms = lines[2:2 + n_center]

    with open(filename, 'w') as f:
        f.write(f"{n_center + len(water_coords)}\n")
        f.write("Alanine + maximally spaced waters in ellipsoid face\n")
        f.writelines(center_atoms)
        for x, y, z in water_coords:
            f.write(f"O {x:.4f} {y:.4f} {z:.4f}\n")

def generate_all_xyz(n=10, output_dir="reference_xyz"):
    os.makedirs(output_dir, exist_ok=True)
    a, b, c = 3.2546, 3.8104, 5.4728
    axes = ['x', 'y', 'z']
    offsets = [-1.0, -0.5, 0.0, 0.5, 1.0]  # 끝, 중간, 중심, 중간, 끝

    for axis in axes:
        ry = {'x': b, 'y': a, 'z': a}[axis]
        rz = {'x': c, 'y': c, 'z': b}[axis]
        for offset in offsets:
            y_coords, z_coords = pack_points_in_ellipse(n=n, ry=ry, rz=rz, steps=1000, lr=0.02)
            coords2d = np.stack([y_coords, z_coords], axis=1)
            coords3d = place_on_plane(coords2d, axis, offset, a, b, c)

            label = f"{offset:+.1f}{axis}".replace(".", "p").replace("+", "plus").replace("-", "minus")
            outpath = os.path.join(output_dir, f"reference_{label}.xyz")
            write_xyz(outpath, coords3d)

generate_all_xyz(n=7)

# %% [markdown]
# ## RMSD

# %%
import os
import numpy as np
from sklearn.cluster import KMeans
from scipy.spatial import procrustes
import shutil
import pandas as pd

# 설정
ref_dir = "./reference_xyz/"
case_dir = "../"
output_dir = "./clustered_cases/"
n_clusters = 10

# 1. 함수 정의
def load_O_coords_from_xyz(path, start_line=15):
    with open(path, 'r') as f:
        lines = f.readlines()[start_line:]
    coords = [list(map(float, line.strip().split()[1:4])) for line in lines if line.strip().startswith('O')]
    return np.array(coords)

def rmsd(a, b):
    if a.shape != b.shape or len(a.shape) != 2:
        raise ValueError(f"Shape mismatch for RMSD: {a.shape} vs {b.shape}")
    mtx1, mtx2, _ = procrustes(a, b)
    return np.sqrt(np.mean((mtx1 - mtx2) ** 2))

# 2. 참조 구조 로드
print("📌 Loading reference structures...")
reference_paths = sorted([os.path.join(ref_dir, f) for f in os.listdir(ref_dir) if f.endswith('.xyz')])
reference_structures = []
for path in reference_paths:
    coords = load_O_coords_from_xyz(path)
    print(f"  Loaded {path} with shape {coords.shape}")
    reference_structures.append(coords)

# 3. 케이스 구조 로드
print("\n📌 Loading case structures...")
case_paths = sorted([os.path.join(case_dir, f) for f in os.listdir(case_dir)
                     if not os.path.isdir(os.path.join(case_dir, f)) and "ref" not in f and f.endswith('.xyz')])
case_names = [os.path.basename(p) for p in case_paths]
case_coords_list = []
for path in case_paths:
    coords = load_O_coords_from_xyz(path)
    print(f"  Loaded {path} with shape {coords.shape}")
    case_coords_list.append(coords)

# 4. RMSD 벡터 생성
print("\n📌 Computing RMSD vectors...")
rmsd_vectors = []
for i, coords in enumerate(case_coords_list):
    vec = []
    for j, ref in enumerate(reference_structures):
        try:
            val = rmsd(coords, ref)
            print(f"    ✓ RMSD case {i} vs ref {j}: {val:.4f}")
            vec.append(val)
        except ValueError as e:
            print(f"    ✗ RMSD case {i} vs ref {j} failed: {e}")
            vec.append(np.nan)
    rmsd_vectors.append(vec)
rmsd_vectors = np.array(rmsd_vectors)

# 5. 결측치 제거 및 클러스터링
print("\n📌 Performing KMeans clustering...")
valid_idx = ~np.isnan(rmsd_vectors).any(axis=1)
filtered_rmsd_vectors = rmsd_vectors[valid_idx]
filtered_case_paths = [p for i, p in enumerate(case_paths) if valid_idx[i]]
filtered_case_names = [n for i, n in enumerate(case_names) if valid_idx[i]]

kmeans = KMeans(n_clusters=n_clusters, random_state=42)
labels = kmeans.fit_predict(filtered_rmsd_vectors)

# 6. 그룹별 폴더 생성 및 파일 복사
print("\n📌 Organizing files into cluster folders...")
for i in range(n_clusters):
    cluster_folder = os.path.join(output_dir, f"cluster_{i}")
    os.makedirs(cluster_folder, exist_ok=True)

for label, case_path in zip(labels, filtered_case_paths):
    shutil.copy(case_path, os.path.join(output_dir, f"cluster_{label}", os.path.basename(case_path)))
    print(f"  → Copied {os.path.basename(case_path)} to cluster_{label}")
# Out:
# 📌 Loading reference structures...
#   Loaded ./reference_xyz/reference_minus0p5x.xyz with shape (7, 3)
#   Loaded ./reference_xyz/reference_minus0p5y.xyz with shape (7, 3)
#   Loaded ./reference_xyz/reference_minus0p5z.xyz with shape (7, 3)
#   Loaded ./reference_xyz/reference_minus1p0x.xyz with shape (7, 3)
#   Loaded ./reference_xyz/reference_minus1p0y.xyz with shape (7, 3)
#   Loaded ./reference_xyz/reference_minus1p0z.xyz with shape (7, 3)
#   Loaded ./reference_xyz/reference_plus0p0x.xyz with shape (7, 3)
#   Loaded ./reference_xyz/reference_plus0p0y.xyz with shape (7, 3)
#   Loaded ./reference_xyz/reference_plus0p0z.xyz with shape (7, 3)
#   Loaded ./reference_xyz/reference_plus0p5x.xyz with shape (7, 3)
#   Loaded ./reference_xyz/reference_plus0p5y.xyz with shape (7, 3)
#   Loaded ./reference_xyz/reference_plus0p5z.xyz with shape (7, 3)
#   Loaded ./reference_xyz/reference_plus1p0x.xyz with shape (7, 3)
#   Loaded ./reference_xyz/reference_plus1p0y.xyz with shape (7, 3)
#   Loaded ./reference_xyz/reference_plus1p0z.xyz with shape (7, 3)
#
# 📌 Loading case structures...
#   Loaded ../case_001.xyz with shape (7, 3)
#   Loaded ../case_002.xyz with shape (7, 3)
#   Loaded ../case_003.xyz with shape (7, 3)
#   Loaded ../case_004.xyz with shape (7, 3)
#   Loaded ../case_007.xyz with shape (7, 3)
#   Loaded ../case_008.xyz with shape (7, 3)
#   Loaded ../case_009.xyz with shape (7, 3)
#   Loaded ../case_010.xyz with shape (7, 3)
#   Loaded ../case_011.xyz with shape (7, 3)
#   Loaded ../case_012.xyz with shape (7, 3)
#   Loaded ../case_014.xyz with shape (7, 3)
#   Loaded ../case_016.xyz with shape (7, 3)
#   Loaded ../case_019.xyz with shape (7, 3)
#   Loaded ../case_020.xyz with shape (7, 3)
#   Loaded ../case_021.xyz with shape (7, 3)
#   Loaded ../case_023.xyz with shape (7, 3)
#   Loaded ../case_024.xyz with shape (7, 3)
#   Loaded ../case_026.xyz with shape (7, 3)
#   Loaded ../case_028.xyz with shape (7, 3)
#   Loaded ../case_029.xyz with shape (7, 3)
#   Loaded ../case_030.xyz with shape (7, 3)
#   Loaded ../case_032.xyz with shape (7, 3)
#   Loaded ../case_033.xyz with shape (7, 3)
#   Loaded ../case_034.xyz with shape (7, 3)
#   Loaded ../case_035.xyz with shape (7, 3)
#   Loaded ../case_038.xyz with shape (7, 3)
#   Loaded ../case_039.xyz with shape (7, 3)
#   Loaded ../case_040.xyz with shape (7, 3)
#   Loaded ../case_042.xyz with shape (7, 3)
#   Loaded ../case_044.xyz with shape (7, 3)
#   Loaded ../case_045.xyz with shape (7, 3)
#   Loaded ../case_046.xyz with shape (7, 3)
#   Loaded ../case_047.xyz with shape (7, 3)
#   Loaded ../case_048.xyz with shape (7, 3)
#   Loaded ../case_049.xyz with shape (7, 3)
#   Loaded ../case_050.xyz with shape (7, 3)
#   Loaded ../case_053.xyz with shape (7, 3)
#   Loaded ../case_054.xyz with shape (7, 3)
#   Loaded ../case_055.xyz with shape (7, 3)
#   Loaded ../case_056.xyz with shape (7, 3)
#   Loaded ../case_057.xyz with shape (7, 3)
#   Loaded ../case_058.xyz with shape (7, 3)
#   Loaded ../case_059.xyz with shape (7, 3)
#   Loaded ../case_062.xyz with shape (7, 3)
#   Loaded ../case_063.xyz with shape (7, 3)
#   Loaded ../case_065.xyz with shape (7, 3)
#   Loaded ../case_066.xyz with shape (7, 3)
#   Loaded ../case_067.xyz with shape (7, 3)
#   Loaded ../case_070.xyz with shape (7, 3)
#   Loaded ../case_071.xyz with shape (7, 3)
#   Loaded ../case_072.xyz with shape (7, 3)
#   Loaded ../case_073.xyz with shape (7, 3)
#   Loaded ../case_074.xyz with shape (7, 3)
#   Loaded ../case_075.xyz with shape (7, 3)
#   Loaded ../case_076.xyz with shape (7, 3)
#   Loaded ../case_077.xyz with shape (7, 3)
#   Loaded ../case_079.xyz with shape (7, 3)
#   Loaded ../case_081.xyz with shape (7, 3)
#   Loaded ../case_082.xyz with shape (7, 3)
#   Loaded ../case_083.xyz with shape (7, 3)
#   Loaded ../case_084.xyz with shape (7, 3)
#   Loaded ../case_085.xyz with shape (7, 3)
#   Loaded ../case_086.xyz with shape (7, 3)
#   Loaded ../case_087.xyz with shape (7, 3)
#   Loaded ../case_088.xyz with shape (7, 3)
#   Loaded ../case_090.xyz with shape (7, 3)
#   Loaded ../case_091.xyz with shape (7, 3)
#   Loaded ../case_094.xyz with shape (7, 3)
#   Loaded ../case_096.xyz with shape (7, 3)
#   Loaded ../case_098.xyz with shape (7, 3)
#   Loaded ../case_099.xyz with shape (7, 3)
#   Loaded ../case_100.xyz with shape (7, 3)
#
# 📌 Computing RMSD vectors...
#     ✓ RMSD case 0 vs ref 0: 0.1871
#     ✓ RMSD case 0 vs ref 1: 0.1783
#     ✓ RMSD case 0 vs ref 2: 0.1962
#     ✓ RMSD case 0 vs ref 3: 0.2043
#     ✓ RMSD case 0 vs ref 4: 0.1820
#     ✓ RMSD case 0 vs ref 5: 0.1944
#     ✓ RMSD case 0 vs ref 6: 0.1892
#     ✓ RMSD case 0 vs ref 7: 0.1927
#     ✓ RMSD case 0 vs ref 8: 0.1945
#     ✓ RMSD case 0 vs ref 9: 0.1680
#     ✓ RMSD case 0 vs ref 10: 0.1718
#     ✓ RMSD case 0 vs ref 11: 0.2143
#     ✓ RMSD case 0 vs ref 12: 0.1945
#     ✓ RMSD case 0 vs ref 13: 0.1964
#     ✓ RMSD case 0 vs ref 14: 0.2042
#     ✓ RMSD case 1 vs ref 0: 0.2064
#     ✓ RMSD case 1 vs ref 1: 0.1862
#     ✓ RMSD case 1 vs ref 2: 0.1843
#     ✓ RMSD case 1 vs ref 3: 0.2015
#     ✓ RMSD case 1 vs ref 4: 0.1985
#     ✓ RMSD case 1 vs ref 5: 0.2028
#     ✓ RMSD case 1 vs ref 6: 0.1860
#     ✓ RMSD case 1 vs ref 7: 0.1650
#     ✓ RMSD case 1 vs ref 8: 0.1765
#     ✓ RMSD case 1 vs ref 9: 0.1871
#     ✓ RMSD case 1 vs ref 10: 0.2071
#     ✓ RMSD case 1 vs ref 11: 0.2008
#     ✓ RMSD case 1 vs ref 12: 0.1960
#     ✓ RMSD case 1 vs ref 13: 0.2098
#     ✓ RMSD case 1 vs ref 14: 0.2049
#     ✓ RMSD case 2 vs ref 0: 0.1967
#     ✓ RMSD case 2 vs ref 1: 0.2054
#     ✓ RMSD case 2 vs ref 2: 0.2103
#     ✓ RMSD case 2 vs ref 3: 0.1948
#     ✓ RMSD case 2 vs ref 4: 0.1983
#     ✓ RMSD case 2 vs ref 5: 0.1807
#     ✓ RMSD case 2 vs ref 6: 0.1907
#     ✓ RMSD case 2 vs ref 7: 0.2060
#     ✓ RMSD case 2 vs ref 8: 0.1814
#     ✓ RMSD case 2 vs ref 9: 0.1925
#     ✓ RMSD case 2 vs ref 10: 0.2126
#     ✓ RMSD case 2 vs ref 11: 0.1698
#     ✓ RMSD case 2 vs ref 12: 0.1909
#     ✓ RMSD case 2 vs ref 13: 0.1980
#     ✓ RMSD case 2 vs ref 14: 0.1907
#     ✓ RMSD case 3 vs ref 0: 0.1919
#     ✓ RMSD case 3 vs ref 1: 0.2042
#     ✓ RMSD case 3 vs ref 2: 0.1962
#     ✓ RMSD case 3 vs ref 3: 0.1971
#     ✓ RMSD case 3 vs ref 4: 0.1786
#     ✓ RMSD case 3 vs ref 5: 0.2001
#     ✓ RMSD case 3 vs ref 6: 0.1678
#     ✓ RMSD case 3 vs ref 7: 0.1973
#     ✓ RMSD case 3 vs ref 8: 0.1829
#     ✓ RMSD case 3 vs ref 9: 0.1844
#     ✓ RMSD case 3 vs ref 10: 0.1444
#     ✓ RMSD case 3 vs ref 11: 0.1938
#     ✓ RMSD case 3 vs ref 12: 0.1995
#     ✓ RMSD case 3 vs ref 13: 0.1973
#     ✓ RMSD case 3 vs ref 14: 0.2106
#     ✓ RMSD case 4 vs ref 0: 0.2026
#     ✓ RMSD case 4 vs ref 1: 0.1756
#     ✓ RMSD case 4 vs ref 2: 0.1819
#     ✓ RMSD case 4 vs ref 3: 0.1872
#     ✓ RMSD case 4 vs ref 4: 0.2012
#     ✓ RMSD case 4 vs ref 5: 0.1943
#     ✓ RMSD case 4 vs ref 6: 0.1814
#     ✓ RMSD case 4 vs ref 7: 0.1549
#     ✓ RMSD case 4 vs ref 8: 0.1770
#     ✓ RMSD case 4 vs ref 9: 0.2013
#     ✓ RMSD case 4 vs ref 10: 0.2056
#     ✓ RMSD case 4 vs ref 11: 0.2028
#     ✓ RMSD case 4 vs ref 12: 0.1941
#     ✓ RMSD case 4 vs ref 13: 0.2071
#     ✓ RMSD case 4 vs ref 14: 0.1979
#     ✓ RMSD case 5 vs ref 0: 0.1880
#     ✓ RMSD case 5 vs ref 1: 0.1930
#     ✓ RMSD case 5 vs ref 2: 0.1825
#     ✓ RMSD case 5 vs ref 3: 0.1273
#     ✓ RMSD case 5 vs ref 4: 0.1949
#     ✓ RMSD case 5 vs ref 5: 0.1411
#     ✓ RMSD case 5 vs ref 6: 0.2049
#     ✓ RMSD case 5 vs ref 7: 0.1666
#     ✓ RMSD case 5 vs ref 8: 0.1986
#     ✓ RMSD case 5 vs ref 9: 0.1975
#     ✓ RMSD case 5 vs ref 10: 0.1820
#     ✓ RMSD case 5 vs ref 11: 0.1848
#     ✓ RMSD case 5 vs ref 12: 0.1781
#     ✓ RMSD case 5 vs ref 13: 0.2051
#     ✓ RMSD case 5 vs ref 14: 0.1887
#     ✓ RMSD case 6 vs ref 0: 0.2062
#     ✓ RMSD case 6 vs ref 1: 0.1679
#     ✓ RMSD case 6 vs ref 2: 0.2072
#     ✓ RMSD case 6 vs ref 3: 0.2077
#     ✓ RMSD case 6 vs ref 4: 0.1588
#     ✓ RMSD case 6 vs ref 5: 0.2017
#     ✓ RMSD case 6 vs ref 6: 0.2090
#     ✓ RMSD case 6 vs ref 7: 0.1778
#     ✓ RMSD case 6 vs ref 8: 0.1692
#     ✓ RMSD case 6 vs ref 9: 0.1794
#     ✓ RMSD case 6 vs ref 10: 0.1963
#     ✓ RMSD case 6 vs ref 11: 0.1890
#     ✓ RMSD case 6 vs ref 12: 0.1923
#     ✓ RMSD case 6 vs ref 13: 0.2130
#     ✓ RMSD case 6 vs ref 14: 0.2148
#     ✓ RMSD case 7 vs ref 0: 0.1967
#     ✓ RMSD case 7 vs ref 1: 0.1872
#     ✓ RMSD case 7 vs ref 2: 0.2045
#     ✓ RMSD case 7 vs ref 3: 0.2014
#     ✓ RMSD case 7 vs ref 4: 0.1739
#     ✓ RMSD case 7 vs ref 5: 0.1951
#     ✓ RMSD case 7 vs ref 6: 0.1958
#     ✓ RMSD case 7 vs ref 7: 0.2031
#     ✓ RMSD case 7 vs ref 8: 0.1696
#     ✓ RMSD case 7 vs ref 9: 0.2075
#     ✓ RMSD case 7 vs ref 10: 0.2120
#     ✓ RMSD case 7 vs ref 11: 0.1557
#     ✓ RMSD case 7 vs ref 12: 0.2007
#     ✓ RMSD case 7 vs ref 13: 0.1872
#     ✓ RMSD case 7 vs ref 14: 0.1609
#     ✓ RMSD case 8 vs ref 0: 0.1957
#     ✓ RMSD case 8 vs ref 1: 0.2016
#     ✓ RMSD case 8 vs ref 2: 0.1984
#     ✓ RMSD case 8 vs ref 3: 0.1425
#     ✓ RMSD case 8 vs ref 4: 0.1979
#     ✓ RMSD case 8 vs ref 5: 0.1388
#     ✓ RMSD case 8 vs ref 6: 0.2015
#     ✓ RMSD case 8 vs ref 7: 0.2036
#     ✓ RMSD case 8 vs ref 8: 0.2069
#     ✓ RMSD case 8 vs ref 9: 0.2023
#     ✓ RMSD case 8 vs ref 10: 0.2048
#     ✓ RMSD case 8 vs ref 11: 0.1821
#     ✓ RMSD case 8 vs ref 12: 0.1975
#     ✓ RMSD case 8 vs ref 13: 0.1759
#     ✓ RMSD case 8 vs ref 14: 0.1349
#     ✓ RMSD case 9 vs ref 0: 0.1918
#     ✓ RMSD case 9 vs ref 1: 0.1915
#     ✓ RMSD case 9 vs ref 2: 0.2082
#     ✓ RMSD case 9 vs ref 3: 0.2002
#     ✓ RMSD case 9 vs ref 4: 0.1500
#     ✓ RMSD case 9 vs ref 5: 0.1991
#     ✓ RMSD case 9 vs ref 6: 0.2037
#     ✓ RMSD case 9 vs ref 7: 0.1940
#     ✓ RMSD case 9 vs ref 8: 0.1782
#     ✓ RMSD case 9 vs ref 9: 0.1910
#     ✓ RMSD case 9 vs ref 10: 0.1763
#     ✓ RMSD case 9 vs ref 11: 0.1680
#     ✓ RMSD case 9 vs ref 12: 0.1626
#     ✓ RMSD case 9 vs ref 13: 0.1911
#     ✓ RMSD case 9 vs ref 14: 0.1898
#     ✓ RMSD case 10 vs ref 0: 0.2059
#     ✓ RMSD case 10 vs ref 1: 0.2024
#     ✓ RMSD case 10 vs ref 2: 0.1980
#     ✓ RMSD case 10 vs ref 3: 0.1932
#     ✓ RMSD case 10 vs ref 4: 0.1865
#     ✓ RMSD case 10 vs ref 5: 0.2039
#     ✓ RMSD case 10 vs ref 6: 0.1421
#     ✓ RMSD case 10 vs ref 7: 0.1906
#     ✓ RMSD case 10 vs ref 8: 0.1980
#     ✓ RMSD case 10 vs ref 9: 0.2124
#     ✓ RMSD case 10 vs ref 10: 0.1802
#     ✓ RMSD case 10 vs ref 11: 0.1762
#     ✓ RMSD case 10 vs ref 12: 0.2057
#     ✓ RMSD case 10 vs ref 13: 0.1794
#     ✓ RMSD case 10 vs ref 14: 0.1318
#     ✓ RMSD case 11 vs ref 0: 0.1480
#     ✓ RMSD case 11 vs ref 1: 0.2132
#     ✓ RMSD case 11 vs ref 2: 0.1642
#     ✓ RMSD case 11 vs ref 3: 0.1866
#     ✓ RMSD case 11 vs ref 4: 0.2072
#     ✓ RMSD case 11 vs ref 5: 0.1739
#     ✓ RMSD case 11 vs ref 6: 0.1660
#     ✓ RMSD case 11 vs ref 7: 0.1991
#     ✓ RMSD case 11 vs ref 8: 0.2068
#     ✓ RMSD case 11 vs ref 9: 0.1714
#     ✓ RMSD case 11 vs ref 10: 0.2028
#     ✓ RMSD case 11 vs ref 11: 0.2068
#     ✓ RMSD case 11 vs ref 12: 0.1393
#     ✓ RMSD case 11 vs ref 13: 0.1806
#     ✓ RMSD case 11 vs ref 14: 0.1450
#     ✓ RMSD case 12 vs ref 0: 0.2020
#     ✓ RMSD case 12 vs ref 1: 0.1834
#     ✓ RMSD case 12 vs ref 2: 0.2056
#     ✓ RMSD case 12 vs ref 3: 0.2072
#     ✓ RMSD case 12 vs ref 4: 0.1364
#     ✓ RMSD case 12 vs ref 5: 0.2029
#     ✓ RMSD case 12 vs ref 6: 0.1910
#     ✓ RMSD case 12 vs ref 7: 0.2140
#     ✓ RMSD case 12 vs ref 8: 0.1153
#     ✓ RMSD case 12 vs ref 9: 0.2058
#     ✓ RMSD case 12 vs ref 10: 0.1881
#     ✓ RMSD case 12 vs ref 11: 0.1669
#     ✓ RMSD case 12 vs ref 12: 0.1917
#     ✓ RMSD case 12 vs ref 13: 0.2081
#     ✓ RMSD case 12 vs ref 14: 0.2138
#     ✓ RMSD case 13 vs ref 0: 0.1831
#     ✓ RMSD case 13 vs ref 1: 0.1947
#     ✓ RMSD case 13 vs ref 2: 0.1826
#     ✓ RMSD case 13 vs ref 3: 0.1861
#     ✓ RMSD case 13 vs ref 4: 0.2074
#     ✓ RMSD case 13 vs ref 5: 0.1849
#     ✓ RMSD case 13 vs ref 6: 0.1968
#     ✓ RMSD case 13 vs ref 7: 0.1892
#     ✓ RMSD case 13 vs ref 8: 0.2024
#     ✓ RMSD case 13 vs ref 9: 0.1789
#     ✓ RMSD case 13 vs ref 10: 0.1556
#     ✓ RMSD case 13 vs ref 11: 0.1953
#     ✓ RMSD case 13 vs ref 12: 0.1966
#     ✓ RMSD case 13 vs ref 13: 0.1819
#     ✓ RMSD case 13 vs ref 14: 0.1924
#     ✓ RMSD case 14 vs ref 0: 0.1824
#     ✓ RMSD case 14 vs ref 1: 0.1920
#     ✓ RMSD case 14 vs ref 2: 0.2028
#     ✓ RMSD case 14 vs ref 3: 0.1943
#     ✓ RMSD case 14 vs ref 4: 0.1787
#     ✓ RMSD case 14 vs ref 5: 0.2010
#     ✓ RMSD case 14 vs ref 6: 0.1547
#     ✓ RMSD case 14 vs ref 7: 0.2007
#     ✓ RMSD case 14 vs ref 8: 0.2057
#     ✓ RMSD case 14 vs ref 9: 0.2094
#     ✓ RMSD case 14 vs ref 10: 0.1797
#     ✓ RMSD case 14 vs ref 11: 0.1919
#     ✓ RMSD case 14 vs ref 12: 0.1725
#     ✓ RMSD case 14 vs ref 13: 0.1509
#     ✓ RMSD case 14 vs ref 14: 0.1272
#     ✓ RMSD case 15 vs ref 0: 0.1946
#     ✓ RMSD case 15 vs ref 1: 0.1995
#     ✓ RMSD case 15 vs ref 2: 0.1913
#     ✓ RMSD case 15 vs ref 3: 0.1422
#     ✓ RMSD case 15 vs ref 4: 0.1886
#     ✓ RMSD case 15 vs ref 5: 0.1616
#     ✓ RMSD case 15 vs ref 6: 0.2089
#     ✓ RMSD case 15 vs ref 7: 0.1931
#     ✓ RMSD case 15 vs ref 8: 0.1442
#     ✓ RMSD case 15 vs ref 9: 0.1934
#     ✓ RMSD case 15 vs ref 10: 0.1777
#     ✓ RMSD case 15 vs ref 11: 0.1600
#     ✓ RMSD case 15 vs ref 12: 0.1953
#     ✓ RMSD case 15 vs ref 13: 0.2086
#     ✓ RMSD case 15 vs ref 14: 0.2003
#     ✓ RMSD case 16 vs ref 0: 0.1753
#     ✓ RMSD case 16 vs ref 1: 0.1987
#     ✓ RMSD case 16 vs ref 2: 0.1893
#     ✓ RMSD case 16 vs ref 3: 0.1718
#     ✓ RMSD case 16 vs ref 4: 0.2087
#     ✓ RMSD case 16 vs ref 5: 0.1545
#     ✓ RMSD case 16 vs ref 6: 0.1919
#     ✓ RMSD case 16 vs ref 7: 0.1797
#     ✓ RMSD case 16 vs ref 8: 0.1985
#     ✓ RMSD case 16 vs ref 9: 0.1320
#     ✓ RMSD case 16 vs ref 10: 0.1767
#     ✓ RMSD case 16 vs ref 11: 0.2136
#     ✓ RMSD case 16 vs ref 12: 0.1583
#     ✓ RMSD case 16 vs ref 13: 0.2019
#     ✓ RMSD case 16 vs ref 14: 0.2108
#     ✓ RMSD case 17 vs ref 0: 0.1936
#     ✓ RMSD case 17 vs ref 1: 0.1809
#     ✓ RMSD case 17 vs ref 2: 0.1883
#     ✓ RMSD case 17 vs ref 3: 0.1607
#     ✓ RMSD case 17 vs ref 4: 0.1665
#     ✓ RMSD case 17 vs ref 5: 0.1761
#     ✓ RMSD case 17 vs ref 6: 0.2091
#     ✓ RMSD case 17 vs ref 7: 0.1751
#     ✓ RMSD case 17 vs ref 8: 0.1772
#     ✓ RMSD case 17 vs ref 9: 0.1873
#     ✓ RMSD case 17 vs ref 10: 0.1685
#     ✓ RMSD case 17 vs ref 11: 0.1741
#     ✓ RMSD case 17 vs ref 12: 0.1669
#     ✓ RMSD case 17 vs ref 13: 0.1810
#     ✓ RMSD case 17 vs ref 14: 0.2062
#     ✓ RMSD case 18 vs ref 0: 0.1718
#     ✓ RMSD case 18 vs ref 1: 0.2004
#     ✓ RMSD case 18 vs ref 2: 0.1685
#     ✓ RMSD case 18 vs ref 3: 0.1819
#     ✓ RMSD case 18 vs ref 4: 0.1760
#     ✓ RMSD case 18 vs ref 5: 0.1991
#     ✓ RMSD case 18 vs ref 6: 0.1887
#     ✓ RMSD case 18 vs ref 7: 0.1794
#     ✓ RMSD case 18 vs ref 8: 0.1863
#     ✓ RMSD case 18 vs ref 9: 0.1732
#     ✓ RMSD case 18 vs ref 10: 0.1591
#     ✓ RMSD case 18 vs ref 11: 0.1752
#     ✓ RMSD case 18 vs ref 12: 0.1740
#     ✓ RMSD case 18 vs ref 13: 0.1746
#     ✓ RMSD case 18 vs ref 14: 0.1784
#     ✓ RMSD case 19 vs ref 0: 0.2019
#     ✓ RMSD case 19 vs ref 1: 0.1853
#     ✓ RMSD case 19 vs ref 2: 0.1719
#     ✓ RMSD case 19 vs ref 3: 0.2137
#     ✓ RMSD case 19 vs ref 4: 0.2002
#     ✓ RMSD case 19 vs ref 5: 0.2115
#     ✓ RMSD case 19 vs ref 6: 0.1710
#     ✓ RMSD case 19 vs ref 7: 0.1932
#     ✓ RMSD case 19 vs ref 8: 0.1871
#     ✓ RMSD case 19 vs ref 9: 0.2008
#     ✓ RMSD case 19 vs ref 10: 0.2088
#     ✓ RMSD case 19 vs ref 11: 0.1854
#     ✓ RMSD case 19 vs ref 12: 0.1975
#     ✓ RMSD case 19 vs ref 13: 0.2064
#     ✓ RMSD case 19 vs ref 14: 0.1999
#     ✓ RMSD case 20 vs ref 0: 0.1563
#     ✓ RMSD case 20 vs ref 1: 0.1666
#     ✓ RMSD case 20 vs ref 2: 0.1703
#     ✓ RMSD case 20 vs ref 3: 0.1801
#     ✓ RMSD case 20 vs ref 4: 0.2094
#     ✓ RMSD case 20 vs ref 5: 0.1708
#     ✓ RMSD case 20 vs ref 6: 0.1691
#     ✓ RMSD case 20 vs ref 7: 0.1631
#     ✓ RMSD case 20 vs ref 8: 0.2032
#     ✓ RMSD case 20 vs ref 9: 0.1378
#     ✓ RMSD case 20 vs ref 10: 0.1981
#     ✓ RMSD case 20 vs ref 11: 0.2081
#     ✓ RMSD case 20 vs ref 12: 0.1438
#     ✓ RMSD case 20 vs ref 13: 0.1738
#     ✓ RMSD case 20 vs ref 14: 0.2013
#     ✓ RMSD case 21 vs ref 0: 0.1915
#     ✓ RMSD case 21 vs ref 1: 0.1996
#     ✓ RMSD case 21 vs ref 2: 0.1485
#     ✓ RMSD case 21 vs ref 3: 0.1395
#     ✓ RMSD case 21 vs ref 4: 0.2129
#     ✓ RMSD case 21 vs ref 5: 0.1152
#     ✓ RMSD case 21 vs ref 6: 0.2040
#     ✓ RMSD case 21 vs ref 7: 0.1754
#     ✓ RMSD case 21 vs ref 8: 0.2008
#     ✓ RMSD case 21 vs ref 9: 0.2046
#     ✓ RMSD case 21 vs ref 10: 0.1980
#     ✓ RMSD case 21 vs ref 11: 0.1856
#     ✓ RMSD case 21 vs ref 12: 0.2021
#     ✓ RMSD case 21 vs ref 13: 0.2065
#     ✓ RMSD case 21 vs ref 14: 0.1772
#     ✓ RMSD case 22 vs ref 0: 0.1943
#     ✓ RMSD case 22 vs ref 1: 0.1909
#     ✓ RMSD case 22 vs ref 2: 0.1780
#     ✓ RMSD case 22 vs ref 3: 0.2082
#     ✓ RMSD case 22 vs ref 4: 0.1920
#     ✓ RMSD case 22 vs ref 5: 0.2042
#     ✓ RMSD case 22 vs ref 6: 0.1793
#     ✓ RMSD case 22 vs ref 7: 0.2068
#     ✓ RMSD case 22 vs ref 8: 0.1795
#     ✓ RMSD case 22 vs ref 9: 0.1987
#     ✓ RMSD case 22 vs ref 10: 0.1823
#     ✓ RMSD case 22 vs ref 11: 0.2018
#     ✓ RMSD case 22 vs ref 12: 0.2072
#     ✓ RMSD case 22 vs ref 13: 0.2117
#     ✓ RMSD case 22 vs ref 14: 0.2090
#     ✓ RMSD case 23 vs ref 0: 0.1938
#     ✓ RMSD case 23 vs ref 1: 0.2066
#     ✓ RMSD case 23 vs ref 2: 0.1783
#     ✓ RMSD case 23 vs ref 3: 0.1701
#     ✓ RMSD case 23 vs ref 4: 0.1978
#     ✓ RMSD case 23 vs ref 5: 0.1702
#     ✓ RMSD case 23 vs ref 6: 0.2052
#     ✓ RMSD case 23 vs ref 7: 0.1751
#     ✓ RMSD case 23 vs ref 8: 0.1913
#     ✓ RMSD case 23 vs ref 9: 0.1956
#     ✓ RMSD case 23 vs ref 10: 0.1890
#     ✓ RMSD case 23 vs ref 11: 0.1723
#     ✓ RMSD case 23 vs ref 12: 0.1913
#     ✓ RMSD case 23 vs ref 13: 0.2091
#     ✓ RMSD case 23 vs ref 14: 0.1931
#     ✓ RMSD case 24 vs ref 0: 0.1585
#     ✓ RMSD case 24 vs ref 1: 0.2032
#     ✓ RMSD case 24 vs ref 2: 0.1609
#     ✓ RMSD case 24 vs ref 3: 0.1939
#     ✓ RMSD case 24 vs ref 4: 0.1939
#     ✓ RMSD case 24 vs ref 5: 0.1866
#     ✓ RMSD case 24 vs ref 6: 0.1439
#     ✓ RMSD case 24 vs ref 7: 0.2159
#     ✓ RMSD case 24 vs ref 8: 0.2007
#     ✓ RMSD case 24 vs ref 9: 0.1961
#     ✓ RMSD case 24 vs ref 10: 0.1881
#     ✓ RMSD case 24 vs ref 11: 0.1946
#     ✓ RMSD case 24 vs ref 12: 0.1557
#     ✓ RMSD case 24 vs ref 13: 0.2082
#     ✓ RMSD case 24 vs ref 14: 0.1842
#     ✓ RMSD case 25 vs ref 0: 0.1747
#     ✓ RMSD case 25 vs ref 1: 0.1753
#     ✓ RMSD case 25 vs ref 2: 0.1812
#     ✓ RMSD case 25 vs ref 3: 0.2099
#     ✓ RMSD case 25 vs ref 4: 0.2007
#     ✓ RMSD case 25 vs ref 5: 0.2069
#     ✓ RMSD case 25 vs ref 6: 0.1653
#     ✓ RMSD case 25 vs ref 7: 0.2049
#     ✓ RMSD case 25 vs ref 8: 0.2070
#     ✓ RMSD case 25 vs ref 9: 0.1413
#     ✓ RMSD case 25 vs ref 10: 0.2162
#     ✓ RMSD case 25 vs ref 11: 0.1941
#     ✓ RMSD case 25 vs ref 12: 0.1323
#     ✓ RMSD case 25 vs ref 13: 0.1794
#     ✓ RMSD case 25 vs ref 14: 0.2041
#     ✓ RMSD case 26 vs ref 0: 0.1689
#     ✓ RMSD case 26 vs ref 1: 0.1989
#     ✓ RMSD case 26 vs ref 2: 0.2020
#     ✓ RMSD case 26 vs ref 3: 0.1944
#     ✓ RMSD case 26 vs ref 4: 0.1892
#     ✓ RMSD case 26 vs ref 5: 0.1869
#     ✓ RMSD case 26 vs ref 6: 0.1855
#     ✓ RMSD case 26 vs ref 7: 0.1802
#     ✓ RMSD case 26 vs ref 8: 0.1851
#     ✓ RMSD case 26 vs ref 9: 0.1357
#     ✓ RMSD case 26 vs ref 10: 0.1637
#     ✓ RMSD case 26 vs ref 11: 0.1881
#     ✓ RMSD case 26 vs ref 12: 0.1675
#     ✓ RMSD case 26 vs ref 13: 0.1607
#     ✓ RMSD case 26 vs ref 14: 0.2040
#     ✓ RMSD case 27 vs ref 0: 0.1873
#     ✓ RMSD case 27 vs ref 1: 0.2007
#     ✓ RMSD case 27 vs ref 2: 0.2004
#     ✓ RMSD case 27 vs ref 3: 0.1909
#     ✓ RMSD case 27 vs ref 4: 0.2004
#     ✓ RMSD case 27 vs ref 5: 0.1954
#     ✓ RMSD case 27 vs ref 6: 0.1836
#     ✓ RMSD case 27 vs ref 7: 0.1682
#     ✓ RMSD case 27 vs ref 8: 0.2050
#     ✓ RMSD case 27 vs ref 9: 0.1704
#     ✓ RMSD case 27 vs ref 10: 0.1891
#     ✓ RMSD case 27 vs ref 11: 0.1890
#     ✓ RMSD case 27 vs ref 12: 0.2039
#     ✓ RMSD case 27 vs ref 13: 0.1611
#     ✓ RMSD case 27 vs ref 14: 0.1786
#     ✓ RMSD case 28 vs ref 0: 0.1859
#     ✓ RMSD case 28 vs ref 1: 0.1394
#     ✓ RMSD case 28 vs ref 2: 0.1575
#     ✓ RMSD case 28 vs ref 3: 0.2075
#     ✓ RMSD case 28 vs ref 4: 0.1842
#     ✓ RMSD case 28 vs ref 5: 0.2026
#     ✓ RMSD case 28 vs ref 6: 0.1826
#     ✓ RMSD case 28 vs ref 7: 0.1818
#     ✓ RMSD case 28 vs ref 8: 0.2096
#     ✓ RMSD case 28 vs ref 9: 0.2003
#     ✓ RMSD case 28 vs ref 10: 0.2004
#     ✓ RMSD case 28 vs ref 11: 0.1924
#     ✓ RMSD case 28 vs ref 12: 0.1757
#     ✓ RMSD case 28 vs ref 13: 0.2027
#     ✓ RMSD case 28 vs ref 14: 0.1847
#     ✓ RMSD case 29 vs ref 0: 0.1538
#     ✓ RMSD case 29 vs ref 1: 0.1980
#     ✓ RMSD case 29 vs ref 2: 0.1997
#     ✓ RMSD case 29 vs ref 3: 0.1665
#     ✓ RMSD case 29 vs ref 4: 0.1987
#     ✓ RMSD case 29 vs ref 5: 0.1606
#     ✓ RMSD case 29 vs ref 6: 0.1812
#     ✓ RMSD case 29 vs ref 7: 0.2101
#     ✓ RMSD case 29 vs ref 8: 0.2050
#     ✓ RMSD case 29 vs ref 9: 0.1893
#     ✓ RMSD case 29 vs ref 10: 0.1733
#     ✓ RMSD case 29 vs ref 11: 0.1854
#     ✓ RMSD case 29 vs ref 12: 0.1729
#     ✓ RMSD case 29 vs ref 13: 0.1636
#     ✓ RMSD case 29 vs ref 14: 0.1647
#     ✓ RMSD case 30 vs ref 0: 0.1543
#     ✓ RMSD case 30 vs ref 1: 0.1925
#     ✓ RMSD case 30 vs ref 2: 0.1887
#     ✓ RMSD case 30 vs ref 3: 0.1886
#     ✓ RMSD case 30 vs ref 4: 0.1961
#     ✓ RMSD case 30 vs ref 5: 0.1515
#     ✓ RMSD case 30 vs ref 6: 0.1932
#     ✓ RMSD case 30 vs ref 7: 0.2033
#     ✓ RMSD case 30 vs ref 8: 0.2051
#     ✓ RMSD case 30 vs ref 9: 0.1823
#     ✓ RMSD case 30 vs ref 10: 0.1960
#     ✓ RMSD case 30 vs ref 11: 0.2013
#     ✓ RMSD case 30 vs ref 12: 0.1611
#     ✓ RMSD case 30 vs ref 13: 0.1753
#     ✓ RMSD case 30 vs ref 14: 0.1670
#     ✓ RMSD case 31 vs ref 0: 0.1390
#     ✓ RMSD case 31 vs ref 1: 0.1701
#     ✓ RMSD case 31 vs ref 2: 0.2004
#     ✓ RMSD case 31 vs ref 3: 0.1894
#     ✓ RMSD case 31 vs ref 4: 0.1764
#     ✓ RMSD case 31 vs ref 5: 0.1810
#     ✓ RMSD case 31 vs ref 6: 0.1929
#     ✓ RMSD case 31 vs ref 7: 0.1959
#     ✓ RMSD case 31 vs ref 8: 0.1804
#     ✓ RMSD case 31 vs ref 9: 0.1702
#     ✓ RMSD case 31 vs ref 10: 0.1608
#     ✓ RMSD case 31 vs ref 11: 0.2140
#     ✓ RMSD case 31 vs ref 12: 0.1433
#     ✓ RMSD case 31 vs ref 13: 0.1965
#     ✓ RMSD case 31 vs ref 14: 0.1974
#     ✓ RMSD case 32 vs ref 0: 0.1782
#     ✓ RMSD case 32 vs ref 1: 0.1966
#     ✓ RMSD case 32 vs ref 2: 0.1877
#     ✓ RMSD case 32 vs ref 3: 0.1940
#     ✓ RMSD case 32 vs ref 4: 0.1904
#     ✓ RMSD case 32 vs ref 5: 0.1808
#     ✓ RMSD case 32 vs ref 6: 0.1783
#     ✓ RMSD case 32 vs ref 7: 0.2104
#     ✓ RMSD case 32 vs ref 8: 0.1786
#     ✓ RMSD case 32 vs ref 9: 0.1914
#     ✓ RMSD case 32 vs ref 10: 0.2033
#     ✓ RMSD case 32 vs ref 11: 0.1891
#     ✓ RMSD case 32 vs ref 12: 0.1634
#     ✓ RMSD case 32 vs ref 13: 0.2123
#     ✓ RMSD case 32 vs ref 14: 0.1796
#     ✓ RMSD case 33 vs ref 0: 0.1995
#     ✓ RMSD case 33 vs ref 1: 0.1961
#     ✓ RMSD case 33 vs ref 2: 0.1076
#     ✓ RMSD case 33 vs ref 3: 0.2098
#     ✓ RMSD case 33 vs ref 4: 0.2123
#     ✓ RMSD case 33 vs ref 5: 0.1951
#     ✓ RMSD case 33 vs ref 6: 0.1573
#     ✓ RMSD case 33 vs ref 7: 0.1822
#     ✓ RMSD case 33 vs ref 8: 0.2025
#     ✓ RMSD case 33 vs ref 9: 0.2067
#     ✓ RMSD case 33 vs ref 10: 0.2114
#     ✓ RMSD case 33 vs ref 11: 0.2096
#     ✓ RMSD case 33 vs ref 12: 0.1822
#     ✓ RMSD case 33 vs ref 13: 0.2141
#     ✓ RMSD case 33 vs ref 14: 0.1920
#     ✓ RMSD case 34 vs ref 0: 0.1953
#     ✓ RMSD case 34 vs ref 1: 0.1897
#     ✓ RMSD case 34 vs ref 2: 0.2058
#     ✓ RMSD case 34 vs ref 3: 0.1746
#     ✓ RMSD case 34 vs ref 4: 0.1782
#     ✓ RMSD case 34 vs ref 5: 0.1997
#     ✓ RMSD case 34 vs ref 6: 0.1788
#     ✓ RMSD case 34 vs ref 7: 0.2060
#     ✓ RMSD case 34 vs ref 8: 0.1939
#     ✓ RMSD case 34 vs ref 9: 0.1968
#     ✓ RMSD case 34 vs ref 10: 0.1938
#     ✓ RMSD case 34 vs ref 11: 0.1408
#     ✓ RMSD case 34 vs ref 12: 0.1891
#     ✓ RMSD case 34 vs ref 13: 0.1608
#     ✓ RMSD case 34 vs ref 14: 0.1726
#     ✓ RMSD case 35 vs ref 0: 0.1830
#     ✓ RMSD case 35 vs ref 1: 0.2111
#     ✓ RMSD case 35 vs ref 2: 0.2049
#     ✓ RMSD case 35 vs ref 3: 0.1897
#     ✓ RMSD case 35 vs ref 4: 0.1908
#     ✓ RMSD case 35 vs ref 5: 0.1965
#     ✓ RMSD case 35 vs ref 6: 0.1927
#     ✓ RMSD case 35 vs ref 7: 0.1829
#     ✓ RMSD case 35 vs ref 8: 0.1759
#     ✓ RMSD case 35 vs ref 9: 0.1389
#     ✓ RMSD case 35 vs ref 10: 0.1593
#     ✓ RMSD case 35 vs ref 11: 0.2030
#     ✓ RMSD case 35 vs ref 12: 0.1938
#     ✓ RMSD case 35 vs ref 13: 0.1582
#     ✓ RMSD case 35 vs ref 14: 0.2085
#     ✓ RMSD case 36 vs ref 0: 0.2026
#     ✓ RMSD case 36 vs ref 1: 0.2081
#     ✓ RMSD case 36 vs ref 2: 0.1674
#     ✓ RMSD case 36 vs ref 3: 0.1936
#     ✓ RMSD case 36 vs ref 4: 0.1858
#     ✓ RMSD case 36 vs ref 5: 0.2126
#     ✓ RMSD case 36 vs ref 6: 0.1728
#     ✓ RMSD case 36 vs ref 7: 0.1895
#     ✓ RMSD case 36 vs ref 8: 0.1764
#     ✓ RMSD case 36 vs ref 9: 0.2107
#     ✓ RMSD case 36 vs ref 10: 0.1727
#     ✓ RMSD case 36 vs ref 11: 0.1883
#     ✓ RMSD case 36 vs ref 12: 0.2016
#     ✓ RMSD case 36 vs ref 13: 0.1656
#     ✓ RMSD case 36 vs ref 14: 0.1789
#     ✓ RMSD case 37 vs ref 0: 0.1879
#     ✓ RMSD case 37 vs ref 1: 0.1787
#     ✓ RMSD case 37 vs ref 2: 0.1992
#     ✓ RMSD case 37 vs ref 3: 0.1916
#     ✓ RMSD case 37 vs ref 4: 0.1976
#     ✓ RMSD case 37 vs ref 5: 0.1859
#     ✓ RMSD case 37 vs ref 6: 0.1859
#     ✓ RMSD case 37 vs ref 7: 0.1925
#     ✓ RMSD case 37 vs ref 8: 0.1698
#     ✓ RMSD case 37 vs ref 9: 0.2081
#     ✓ RMSD case 37 vs ref 10: 0.2083
#     ✓ RMSD case 37 vs ref 11: 0.1552
#     ✓ RMSD case 37 vs ref 12: 0.1997
#     ✓ RMSD case 37 vs ref 13: 0.1950
#     ✓ RMSD case 37 vs ref 14: 0.1749
#     ✓ RMSD case 38 vs ref 0: 0.2014
#     ✓ RMSD case 38 vs ref 1: 0.2010
#     ✓ RMSD case 38 vs ref 2: 0.2011
#     ✓ RMSD case 38 vs ref 3: 0.1336
#     ✓ RMSD case 38 vs ref 4: 0.2085
#     ✓ RMSD case 38 vs ref 5: 0.1680
#     ✓ RMSD case 38 vs ref 6: 0.2018
#     ✓ RMSD case 38 vs ref 7: 0.2006
#     ✓ RMSD case 38 vs ref 8: 0.1986
#     ✓ RMSD case 38 vs ref 9: 0.2037
#     ✓ RMSD case 38 vs ref 10: 0.1870
#     ✓ RMSD case 38 vs ref 11: 0.1299
#     ✓ RMSD case 38 vs ref 12: 0.2007
#     ✓ RMSD case 38 vs ref 13: 0.1720
#     ✓ RMSD case 38 vs ref 14: 0.1748
#     ✓ RMSD case 39 vs ref 0: 0.1653
#     ✓ RMSD case 39 vs ref 1: 0.1998
#     ✓ RMSD case 39 vs ref 2: 0.1638
#     ✓ RMSD case 39 vs ref 3: 0.1950
#     ✓ RMSD case 39 vs ref 4: 0.2027
#     ✓ RMSD case 39 vs ref 5: 0.1694
#     ✓ RMSD case 39 vs ref 6: 0.1894
#     ✓ RMSD case 39 vs ref 7: 0.1856
#     ✓ RMSD case 39 vs ref 8: 0.2111
#     ✓ RMSD case 39 vs ref 9: 0.1938
#     ✓ RMSD case 39 vs ref 10: 0.2127
#     ✓ RMSD case 39 vs ref 11: 0.2100
#     ✓ RMSD case 39 vs ref 12: 0.1575
#     ✓ RMSD case 39 vs ref 13: 0.1871
#     ✓ RMSD case 39 vs ref 14: 0.1599
#     ✓ RMSD case 40 vs ref 0: 0.2039
#     ✓ RMSD case 40 vs ref 1: 0.1850
#     ✓ RMSD case 40 vs ref 2: 0.1847
#     ✓ RMSD case 40 vs ref 3: 0.1305
#     ✓ RMSD case 40 vs ref 4: 0.2115
#     ✓ RMSD case 40 vs ref 5: 0.1542
#     ✓ RMSD case 40 vs ref 6: 0.1887
#     ✓ RMSD case 40 vs ref 7: 0.1904
#     ✓ RMSD case 40 vs ref 8: 0.1994
#     ✓ RMSD case 40 vs ref 9: 0.1978
#     ✓ RMSD case 40 vs ref 10: 0.2075
#     ✓ RMSD case 40 vs ref 11: 0.1565
#     ✓ RMSD case 40 vs ref 12: 0.1959
#     ✓ RMSD case 40 vs ref 13: 0.1732
#     ✓ RMSD case 40 vs ref 14: 0.1692
#     ✓ RMSD case 41 vs ref 0: 0.1610
#     ✓ RMSD case 41 vs ref 1: 0.2129
#     ✓ RMSD case 41 vs ref 2: 0.1895
#     ✓ RMSD case 41 vs ref 3: 0.1751
#     ✓ RMSD case 41 vs ref 4: 0.1929
#     ✓ RMSD case 41 vs ref 5: 0.1641
#     ✓ RMSD case 41 vs ref 6: 0.1817
#     ✓ RMSD case 41 vs ref 7: 0.1980
#     ✓ RMSD case 41 vs ref 8: 0.1877
#     ✓ RMSD case 41 vs ref 9: 0.1890
#     ✓ RMSD case 41 vs ref 10: 0.1943
#     ✓ RMSD case 41 vs ref 11: 0.1886
#     ✓ RMSD case 41 vs ref 12: 0.1890
#     ✓ RMSD case 41 vs ref 13: 0.1966
#     ✓ RMSD case 41 vs ref 14: 0.1689
#     ✓ RMSD case 42 vs ref 0: 0.1383
#     ✓ RMSD case 42 vs ref 1: 0.1730
#     ✓ RMSD case 42 vs ref 2: 0.1983
#     ✓ RMSD case 42 vs ref 3: 0.2053
#     ✓ RMSD case 42 vs ref 4: 0.2082
#     ✓ RMSD case 42 vs ref 5: 0.1967
#     ✓ RMSD case 42 vs ref 6: 0.1764
#     ✓ RMSD case 42 vs ref 7: 0.1747
#     ✓ RMSD case 42 vs ref 8: 0.2035
#     ✓ RMSD case 42 vs ref 9: 0.1654
#     ✓ RMSD case 42 vs ref 10: 0.1989
#     ✓ RMSD case 42 vs ref 11: 0.2108
#     ✓ RMSD case 42 vs ref 12: 0.1680
#     ✓ RMSD case 42 vs ref 13: 0.1579
#     ✓ RMSD case 42 vs ref 14: 0.1982
#     ✓ RMSD case 43 vs ref 0: 0.2003
#     ✓ RMSD case 43 vs ref 1: 0.2023
#     ✓ RMSD case 43 vs ref 2: 0.1862
#     ✓ RMSD case 43 vs ref 3: 0.1779
#     ✓ RMSD case 43 vs ref 4: 0.1837
#     ✓ RMSD case 43 vs ref 5: 0.1912
#     ✓ RMSD case 43 vs ref 6: 0.1642
#     ✓ RMSD case 43 vs ref 7: 0.2021
#     ✓ RMSD case 43 vs ref 8: 0.1690
#     ✓ RMSD case 43 vs ref 9: 0.2023
#     ✓ RMSD case 43 vs ref 10: 0.1997
#     ✓ RMSD case 43 vs ref 11: 0.1268
#     ✓ RMSD case 43 vs ref 12: 0.1930
#     ✓ RMSD case 43 vs ref 13: 0.1815
#     ✓ RMSD case 43 vs ref 14: 0.1466
#     ✓ RMSD case 44 vs ref 0: 0.1593
#     ✓ RMSD case 44 vs ref 1: 0.2035
#     ✓ RMSD case 44 vs ref 2: 0.1416
#     ✓ RMSD case 44 vs ref 3: 0.1684
#     ✓ RMSD case 44 vs ref 4: 0.1915
#     ✓ RMSD case 44 vs ref 5: 0.1519
#     ✓ RMSD case 44 vs ref 6: 0.1993
#     ✓ RMSD case 44 vs ref 7: 0.1865
#     ✓ RMSD case 44 vs ref 8: 0.1902
#     ✓ RMSD case 44 vs ref 9: 0.1895
#     ✓ RMSD case 44 vs ref 10: 0.1822
#     ✓ RMSD case 44 vs ref 11: 0.1916
#     ✓ RMSD case 44 vs ref 12: 0.1485
#     ✓ RMSD case 44 vs ref 13: 0.2065
#     ✓ RMSD case 44 vs ref 14: 0.1828
#     ✓ RMSD case 45 vs ref 0: 0.2020
#     ✓ RMSD case 45 vs ref 1: 0.2127
#     ✓ RMSD case 45 vs ref 2: 0.1751
#     ✓ RMSD case 45 vs ref 3: 0.1759
#     ✓ RMSD case 45 vs ref 4: 0.1872
#     ✓ RMSD case 45 vs ref 5: 0.1909
#     ✓ RMSD case 45 vs ref 6: 0.2014
#     ✓ RMSD case 45 vs ref 7: 0.2071
#     ✓ RMSD case 45 vs ref 8: 0.1644
#     ✓ RMSD case 45 vs ref 9: 0.2032
#     ✓ RMSD case 45 vs ref 10: 0.1627
#     ✓ RMSD case 45 vs ref 11: 0.1355
#     ✓ RMSD case 45 vs ref 12: 0.2011
#     ✓ RMSD case 45 vs ref 13: 0.2114
#     ✓ RMSD case 45 vs ref 14: 0.2008
#     ✓ RMSD case 46 vs ref 0: 0.1730
#     ✓ RMSD case 46 vs ref 1: 0.1905
#     ✓ RMSD case 46 vs ref 2: 0.1574
#     ✓ RMSD case 46 vs ref 3: 0.1917
#     ✓ RMSD case 46 vs ref 4: 0.1898
#     ✓ RMSD case 46 vs ref 5: 0.2048
#     ✓ RMSD case 46 vs ref 6: 0.1757
#     ✓ RMSD case 46 vs ref 7: 0.1837
#     ✓ RMSD case 46 vs ref 8: 0.1737
#     ✓ RMSD case 46 vs ref 9: 0.1941
#     ✓ RMSD case 46 vs ref 10: 0.1691
#     ✓ RMSD case 46 vs ref 11: 0.1919
#     ✓ RMSD case 46 vs ref 12: 0.1896
#     ✓ RMSD case 46 vs ref 13: 0.1906
#     ✓ RMSD case 46 vs ref 14: 0.1890
#     ✓ RMSD case 47 vs ref 0: 0.1849
#     ✓ RMSD case 47 vs ref 1: 0.1828
#     ✓ RMSD case 47 vs ref 2: 0.1917
#     ✓ RMSD case 47 vs ref 3: 0.1857
#     ✓ RMSD case 47 vs ref 4: 0.1914
#     ✓ RMSD case 47 vs ref 5: 0.1675
#     ✓ RMSD case 47 vs ref 6: 0.2021
#     ✓ RMSD case 47 vs ref 7: 0.2047
#     ✓ RMSD case 47 vs ref 8: 0.1875
#     ✓ RMSD case 47 vs ref 9: 0.1824
#     ✓ RMSD case 47 vs ref 10: 0.2012
#     ✓ RMSD case 47 vs ref 11: 0.2086
#     ✓ RMSD case 47 vs ref 12: 0.1904
#     ✓ RMSD case 47 vs ref 13: 0.1998
#     ✓ RMSD case 47 vs ref 14: 0.1948
#     ✓ RMSD case 48 vs ref 0: 0.1798
#     ✓ RMSD case 48 vs ref 1: 0.1822
#     ✓ RMSD case 48 vs ref 2: 0.1666
#     ✓ RMSD case 48 vs ref 3: 0.2152
#     ✓ RMSD case 48 vs ref 4: 0.1855
#     ✓ RMSD case 48 vs ref 5: 0.2096
#     ✓ RMSD case 48 vs ref 6: 0.1934
#     ✓ RMSD case 48 vs ref 7: 0.1739
#     ✓ RMSD case 48 vs ref 8: 0.1833
#     ✓ RMSD case 48 vs ref 9: 0.1792
#     ✓ RMSD case 48 vs ref 10: 0.1872
#     ✓ RMSD case 48 vs ref 11: 0.2044
#     ✓ RMSD case 48 vs ref 12: 0.1861
#     ✓ RMSD case 48 vs ref 13: 0.1347
#     ✓ RMSD case 48 vs ref 14: 0.1818
#     ✓ RMSD case 49 vs ref 0: 0.2125
#     ✓ RMSD case 49 vs ref 1: 0.1925
#     ✓ RMSD case 49 vs ref 2: 0.2108
#     ✓ RMSD case 49 vs ref 3: 0.1975
#     ✓ RMSD case 49 vs ref 4: 0.1581
#     ✓ RMSD case 49 vs ref 5: 0.2102
#     ✓ RMSD case 49 vs ref 6: 0.1844
#     ✓ RMSD case 49 vs ref 7: 0.1872
#     ✓ RMSD case 49 vs ref 8: 0.1785
#     ✓ RMSD case 49 vs ref 9: 0.2058
#     ✓ RMSD case 49 vs ref 10: 0.1816
#     ✓ RMSD case 49 vs ref 11: 0.1628
#     ✓ RMSD case 49 vs ref 12: 0.1981
#     ✓ RMSD case 49 vs ref 13: 0.1945
#     ✓ RMSD case 49 vs ref 14: 0.1864
#     ✓ RMSD case 50 vs ref 0: 0.1888
#     ✓ RMSD case 50 vs ref 1: 0.1974
#     ✓ RMSD case 50 vs ref 2: 0.2135
#     ✓ RMSD case 50 vs ref 3: 0.2091
#     ✓ RMSD case 50 vs ref 4: 0.1750
#     ✓ RMSD case 50 vs ref 5: 0.1966
#     ✓ RMSD case 50 vs ref 6: 0.2069
#     ✓ RMSD case 50 vs ref 7: 0.1971
#     ✓ RMSD case 50 vs ref 8: 0.1565
#     ✓ RMSD case 50 vs ref 9: 0.1947
#     ✓ RMSD case 50 vs ref 10: 0.2072
#     ✓ RMSD case 50 vs ref 11: 0.2012
#     ✓ RMSD case 50 vs ref 12: 0.1924
#     ✓ RMSD case 50 vs ref 13: 0.2010
#     ✓ RMSD case 50 vs ref 14: 0.1985
#     ✓ RMSD case 51 vs ref 0: 0.2001
#     ✓ RMSD case 51 vs ref 1: 0.1817
#     ✓ RMSD case 51 vs ref 2: 0.1780
#     ✓ RMSD case 51 vs ref 3: 0.1753
#     ✓ RMSD case 51 vs ref 4: 0.2057
#     ✓ RMSD case 51 vs ref 5: 0.1759
#     ✓ RMSD case 51 vs ref 6: 0.1746
#     ✓ RMSD case 51 vs ref 7: 0.2015
#     ✓ RMSD case 51 vs ref 8: 0.2080
#     ✓ RMSD case 51 vs ref 9: 0.1773
#     ✓ RMSD case 51 vs ref 10: 0.2065
#     ✓ RMSD case 51 vs ref 11: 0.1930
#     ✓ RMSD case 51 vs ref 12: 0.1841
#     ✓ RMSD case 51 vs ref 13: 0.1988
#     ✓ RMSD case 51 vs ref 14: 0.1920
#     ✓ RMSD case 52 vs ref 0: 0.1579
#     ✓ RMSD case 52 vs ref 1: 0.1826
#     ✓ RMSD case 52 vs ref 2: 0.1813
#     ✓ RMSD case 52 vs ref 3: 0.2039
#     ✓ RMSD case 52 vs ref 4: 0.1916
#     ✓ RMSD case 52 vs ref 5: 0.1974
#     ✓ RMSD case 52 vs ref 6: 0.1733
#     ✓ RMSD case 52 vs ref 7: 0.1873
#     ✓ RMSD case 52 vs ref 8: 0.1717
#     ✓ RMSD case 52 vs ref 9: 0.1759
#     ✓ RMSD case 52 vs ref 10: 0.2080
#     ✓ RMSD case 52 vs ref 11: 0.1873
#     ✓ RMSD case 52 vs ref 12: 0.1622
#     ✓ RMSD case 52 vs ref 13: 0.1533
#     ✓ RMSD case 52 vs ref 14: 0.1724
#     ✓ RMSD case 53 vs ref 0: 0.1543
#     ✓ RMSD case 53 vs ref 1: 0.2015
#     ✓ RMSD case 53 vs ref 2: 0.2000
#     ✓ RMSD case 53 vs ref 3: 0.1953
#     ✓ RMSD case 53 vs ref 4: 0.1301
#     ✓ RMSD case 53 vs ref 5: 0.1949
#     ✓ RMSD case 53 vs ref 6: 0.2097
#     ✓ RMSD case 53 vs ref 7: 0.1942
#     ✓ RMSD case 53 vs ref 8: 0.1540
#     ✓ RMSD case 53 vs ref 9: 0.1735
#     ✓ RMSD case 53 vs ref 10: 0.1625
#     ✓ RMSD case 53 vs ref 11: 0.1984
#     ✓ RMSD case 53 vs ref 12: 0.1816
#     ✓ RMSD case 53 vs ref 13: 0.1724
#     ✓ RMSD case 53 vs ref 14: 0.1577
#     ✓ RMSD case 54 vs ref 0: 0.1990
#     ✓ RMSD case 54 vs ref 1: 0.1728
#     ✓ RMSD case 54 vs ref 2: 0.1437
#     ✓ RMSD case 54 vs ref 3: 0.1913
#     ✓ RMSD case 54 vs ref 4: 0.1957
#     ✓ RMSD case 54 vs ref 5: 0.1866
#     ✓ RMSD case 54 vs ref 6: 0.2009
#     ✓ RMSD case 54 vs ref 7: 0.1762
#     ✓ RMSD case 54 vs ref 8: 0.1771
#     ✓ RMSD case 54 vs ref 9: 0.1609
#     ✓ RMSD case 54 vs ref 10: 0.1931
#     ✓ RMSD case 54 vs ref 11: 0.1805
#     ✓ RMSD case 54 vs ref 12: 0.1771
#     ✓ RMSD case 54 vs ref 13: 0.2100
#     ✓ RMSD case 54 vs ref 14: 0.2149
#     ✓ RMSD case 55 vs ref 0: 0.1984
#     ✓ RMSD case 55 vs ref 1: 0.1956
#     ✓ RMSD case 55 vs ref 2: 0.1754
#     ✓ RMSD case 55 vs ref 3: 0.1595
#     ✓ RMSD case 55 vs ref 4: 0.1826
#     ✓ RMSD case 55 vs ref 5: 0.1620
#     ✓ RMSD case 55 vs ref 6: 0.2108
#     ✓ RMSD case 55 vs ref 7: 0.1542
#     ✓ RMSD case 55 vs ref 8: 0.1764
#     ✓ RMSD case 55 vs ref 9: 0.1630
#     ✓ RMSD case 55 vs ref 10: 0.1946
#     ✓ RMSD case 55 vs ref 11: 0.1914
#     ✓ RMSD case 55 vs ref 12: 0.1818
#     ✓ RMSD case 55 vs ref 13: 0.2014
#     ✓ RMSD case 55 vs ref 14: 0.2052
#     ✓ RMSD case 56 vs ref 0: 0.1645
#     ✓ RMSD case 56 vs ref 1: 0.2096
#     ✓ RMSD case 56 vs ref 2: 0.1867
#     ✓ RMSD case 56 vs ref 3: 0.1751
#     ✓ RMSD case 56 vs ref 4: 0.2011
#     ✓ RMSD case 56 vs ref 5: 0.1766
#     ✓ RMSD case 56 vs ref 6: 0.1761
#     ✓ RMSD case 56 vs ref 7: 0.1818
#     ✓ RMSD case 56 vs ref 8: 0.1861
#     ✓ RMSD case 56 vs ref 9: 0.1291
#     ✓ RMSD case 56 vs ref 10: 0.1580
#     ✓ RMSD case 56 vs ref 11: 0.2042
#     ✓ RMSD case 56 vs ref 12: 0.1739
#     ✓ RMSD case 56 vs ref 13: 0.1666
#     ✓ RMSD case 56 vs ref 14: 0.2054
#     ✓ RMSD case 57 vs ref 0: 0.1769
#     ✓ RMSD case 57 vs ref 1: 0.1518
#     ✓ RMSD case 57 vs ref 2: 0.1846
#     ✓ RMSD case 57 vs ref 3: 0.1906
#     ✓ RMSD case 57 vs ref 4: 0.1969
#     ✓ RMSD case 57 vs ref 5: 0.1974
#     ✓ RMSD case 57 vs ref 6: 0.1876
#     ✓ RMSD case 57 vs ref 7: 0.1389
#     ✓ RMSD case 57 vs ref 8: 0.2012
#     ✓ RMSD case 57 vs ref 9: 0.1983
#     ✓ RMSD case 57 vs ref 10: 0.2020
#     ✓ RMSD case 57 vs ref 11: 0.1913
#     ✓ RMSD case 57 vs ref 12: 0.1955
#     ✓ RMSD case 57 vs ref 13: 0.1827
#     ✓ RMSD case 57 vs ref 14: 0.1848
#     ✓ RMSD case 58 vs ref 0: 0.1828
#     ✓ RMSD case 58 vs ref 1: 0.1749
#     ✓ RMSD case 58 vs ref 2: 0.1562
#     ✓ RMSD case 58 vs ref 3: 0.2107
#     ✓ RMSD case 58 vs ref 4: 0.1971
#     ✓ RMSD case 58 vs ref 5: 0.2098
#     ✓ RMSD case 58 vs ref 6: 0.1368
#     ✓ RMSD case 58 vs ref 7: 0.2065
#     ✓ RMSD case 58 vs ref 8: 0.2025
#     ✓ RMSD case 58 vs ref 9: 0.1957
#     ✓ RMSD case 58 vs ref 10: 0.1933
#     ✓ RMSD case 58 vs ref 11: 0.1938
#     ✓ RMSD case 58 vs ref 12: 0.1709
#     ✓ RMSD case 58 vs ref 13: 0.1894
#     ✓ RMSD case 58 vs ref 14: 0.1985
#     ✓ RMSD case 59 vs ref 0: 0.1848
#     ✓ RMSD case 59 vs ref 1: 0.1594
#     ✓ RMSD case 59 vs ref 2: 0.1887
#     ✓ RMSD case 59 vs ref 3: 0.1698
#     ✓ RMSD case 59 vs ref 4: 0.2007
#     ✓ RMSD case 59 vs ref 5: 0.1493
#     ✓ RMSD case 59 vs ref 6: 0.2007
#     ✓ RMSD case 59 vs ref 7: 0.1915
#     ✓ RMSD case 59 vs ref 8: 0.2072
#     ✓ RMSD case 59 vs ref 9: 0.1632
#     ✓ RMSD case 59 vs ref 10: 0.1858
#     ✓ RMSD case 59 vs ref 11: 0.1983
#     ✓ RMSD case 59 vs ref 12: 0.1747
#     ✓ RMSD case 59 vs ref 13: 0.1607
#     ✓ RMSD case 59 vs ref 14: 0.1981
#     ✓ RMSD case 60 vs ref 0: 0.1903
#     ✓ RMSD case 60 vs ref 1: 0.1856
#     ✓ RMSD case 60 vs ref 2: 0.1985
#     ✓ RMSD case 60 vs ref 3: 0.1596
#     ✓ RMSD case 60 vs ref 4: 0.2131
#     ✓ RMSD case 60 vs ref 5: 0.1496
#     ✓ RMSD case 60 vs ref 6: 0.2076
#     ✓ RMSD case 60 vs ref 7: 0.1818
#     ✓ RMSD case 60 vs ref 8: 0.2073
#     ✓ RMSD case 60 vs ref 9: 0.1672
#     ✓ RMSD case 60 vs ref 10: 0.1980
#     ✓ RMSD case 60 vs ref 11: 0.1982
#     ✓ RMSD case 60 vs ref 12: 0.1926
#     ✓ RMSD case 60 vs ref 13: 0.1638
#     ✓ RMSD case 60 vs ref 14: 0.1923
#     ✓ RMSD case 61 vs ref 0: 0.1428
#     ✓ RMSD case 61 vs ref 1: 0.1776
#     ✓ RMSD case 61 vs ref 2: 0.1691
#     ✓ RMSD case 61 vs ref 3: 0.2103
#     ✓ RMSD case 61 vs ref 4: 0.1951
#     ✓ RMSD case 61 vs ref 5: 0.1878
#     ✓ RMSD case 61 vs ref 6: 0.1976
#     ✓ RMSD case 61 vs ref 7: 0.1795
#     ✓ RMSD case 61 vs ref 8: 0.1940
#     ✓ RMSD case 61 vs ref 9: 0.1849
#     ✓ RMSD case 61 vs ref 10: 0.2169
#     ✓ RMSD case 61 vs ref 11: 0.2134
#     ✓ RMSD case 61 vs ref 12: 0.1554
#     ✓ RMSD case 61 vs ref 13: 0.1737
#     ✓ RMSD case 61 vs ref 14: 0.1811
#     ✓ RMSD case 62 vs ref 0: 0.1822
#     ✓ RMSD case 62 vs ref 1: 0.2067
#     ✓ RMSD case 62 vs ref 2: 0.2013
#     ✓ RMSD case 62 vs ref 3: 0.1696
#     ✓ RMSD case 62 vs ref 4: 0.1910
#     ✓ RMSD case 62 vs ref 5: 0.1711
#     ✓ RMSD case 62 vs ref 6: 0.2010
#     ✓ RMSD case 62 vs ref 7: 0.1790
#     ✓ RMSD case 62 vs ref 8: 0.1719
#     ✓ RMSD case 62 vs ref 9: 0.1574
#     ✓ RMSD case 62 vs ref 10: 0.1819
#     ✓ RMSD case 62 vs ref 11: 0.1988
#     ✓ RMSD case 62 vs ref 12: 0.1867
#     ✓ RMSD case 62 vs ref 13: 0.1779
#     ✓ RMSD case 62 vs ref 14: 0.1940
#     ✓ RMSD case 63 vs ref 0: 0.1678
#     ✓ RMSD case 63 vs ref 1: 0.2008
#     ✓ RMSD case 63 vs ref 2: 0.2051
#     ✓ RMSD case 63 vs ref 3: 0.1713
#     ✓ RMSD case 63 vs ref 4: 0.2041
#     ✓ RMSD case 63 vs ref 5: 0.1592
#     ✓ RMSD case 63 vs ref 6: 0.2050
#     ✓ RMSD case 63 vs ref 7: 0.2165
#     ✓ RMSD case 63 vs ref 8: 0.2112
#     ✓ RMSD case 63 vs ref 9: 0.1837
#     ✓ RMSD case 63 vs ref 10: 0.1629
#     ✓ RMSD case 63 vs ref 11: 0.1855
#     ✓ RMSD case 63 vs ref 12: 0.1755
#     ✓ RMSD case 63 vs ref 13: 0.1835
#     ✓ RMSD case 63 vs ref 14: 0.1856
#     ✓ RMSD case 64 vs ref 0: 0.1464
#     ✓ RMSD case 64 vs ref 1: 0.2036
#     ✓ RMSD case 64 vs ref 2: 0.1816
#     ✓ RMSD case 64 vs ref 3: 0.1793
#     ✓ RMSD case 64 vs ref 4: 0.2062
#     ✓ RMSD case 64 vs ref 5: 0.1605
#     ✓ RMSD case 64 vs ref 6: 0.1625
#     ✓ RMSD case 64 vs ref 7: 0.2063
#     ✓ RMSD case 64 vs ref 8: 0.2105
#     ✓ RMSD case 64 vs ref 9: 0.1543
#     ✓ RMSD case 64 vs ref 10: 0.2084
#     ✓ RMSD case 64 vs ref 11: 0.1904
#     ✓ RMSD case 64 vs ref 12: 0.1507
#     ✓ RMSD case 64 vs ref 13: 0.2051
#     ✓ RMSD case 64 vs ref 14: 0.1701
#     ✓ RMSD case 65 vs ref 0: 0.1712
#     ✓ RMSD case 65 vs ref 1: 0.1966
#     ✓ RMSD case 65 vs ref 2: 0.2045
#     ✓ RMSD case 65 vs ref 3: 0.2015
#     ✓ RMSD case 65 vs ref 4: 0.1997
#     ✓ RMSD case 65 vs ref 5: 0.1829
#     ✓ RMSD case 65 vs ref 6: 0.1813
#     ✓ RMSD case 65 vs ref 7: 0.1948
#     ✓ RMSD case 65 vs ref 8: 0.1891
#     ✓ RMSD case 65 vs ref 9: 0.1593
#     ✓ RMSD case 65 vs ref 10: 0.1896
#     ✓ RMSD case 65 vs ref 11: 0.2082
#     ✓ RMSD case 65 vs ref 12: 0.1938
#     ✓ RMSD case 65 vs ref 13: 0.2043
#     ✓ RMSD case 65 vs ref 14: 0.2074
#     ✓ RMSD case 66 vs ref 0: 0.1973
#     ✓ RMSD case 66 vs ref 1: 0.1909
#     ✓ RMSD case 66 vs ref 2: 0.2036
#     ✓ RMSD case 66 vs ref 3: 0.2057
#     ✓ RMSD case 66 vs ref 4: 0.2002
#     ✓ RMSD case 66 vs ref 5: 0.1957
#     ✓ RMSD case 66 vs ref 6: 0.1455
#     ✓ RMSD case 66 vs ref 7: 0.2157
#     ✓ RMSD case 66 vs ref 8: 0.2125
#     ✓ RMSD case 66 vs ref 9: 0.1791
#     ✓ RMSD case 66 vs ref 10: 0.2030
#     ✓ RMSD case 66 vs ref 11: 0.1985
#     ✓ RMSD case 66 vs ref 12: 0.1939
#     ✓ RMSD case 66 vs ref 13: 0.1924
#     ✓ RMSD case 66 vs ref 14: 0.1912
#     ✓ RMSD case 67 vs ref 0: 0.2065
#     ✓ RMSD case 67 vs ref 1: 0.1666
#     ✓ RMSD case 67 vs ref 2: 0.1921
#     ✓ RMSD case 67 vs ref 3: 0.1762
#     ✓ RMSD case 67 vs ref 4: 0.1539
#     ✓ RMSD case 67 vs ref 5: 0.1914
#     ✓ RMSD case 67 vs ref 6: 0.2064
#     ✓ RMSD case 67 vs ref 7: 0.1716
#     ✓ RMSD case 67 vs ref 8: 0.1739
#     ✓ RMSD case 67 vs ref 9: 0.2121
#     ✓ RMSD case 67 vs ref 10: 0.1725
#     ✓ RMSD case 67 vs ref 11: 0.1593
#     ✓ RMSD case 67 vs ref 12: 0.2023
#     ✓ RMSD case 67 vs ref 13: 0.2050
#     ✓ RMSD case 67 vs ref 14: 0.2045
#     ✓ RMSD case 68 vs ref 0: 0.1683
#     ✓ RMSD case 68 vs ref 1: 0.1917
#     ✓ RMSD case 68 vs ref 2: 0.1819
#     ✓ RMSD case 68 vs ref 3: 0.2089
#     ✓ RMSD case 68 vs ref 4: 0.1831
#     ✓ RMSD case 68 vs ref 5: 0.2054
#     ✓ RMSD case 68 vs ref 6: 0.1502
#     ✓ RMSD case 68 vs ref 7: 0.2044
#     ✓ RMSD case 68 vs ref 8: 0.1945
#     ✓ RMSD case 68 vs ref 9: 0.1856
#     ✓ RMSD case 68 vs ref 10: 0.1964
#     ✓ RMSD case 68 vs ref 11: 0.2038
#     ✓ RMSD case 68 vs ref 12: 0.1585
#     ✓ RMSD case 68 vs ref 13: 0.1575
#     ✓ RMSD case 68 vs ref 14: 0.1787
#     ✓ RMSD case 69 vs ref 0: 0.1852
#     ✓ RMSD case 69 vs ref 1: 0.2107
#     ✓ RMSD case 69 vs ref 2: 0.2120
#     ✓ RMSD case 69 vs ref 3: 0.1755
#     ✓ RMSD case 69 vs ref 4: 0.1510
#     ✓ RMSD case 69 vs ref 5: 0.1800
#     ✓ RMSD case 69 vs ref 6: 0.1903
#     ✓ RMSD case 69 vs ref 7: 0.2016
#     ✓ RMSD case 69 vs ref 8: 0.1799
#     ✓ RMSD case 69 vs ref 9: 0.1781
#     ✓ RMSD case 69 vs ref 10: 0.1783
#     ✓ RMSD case 69 vs ref 11: 0.1668
#     ✓ RMSD case 69 vs ref 12: 0.1843
#     ✓ RMSD case 69 vs ref 13: 0.1960
#     ✓ RMSD case 69 vs ref 14: 0.1707
#     ✓ RMSD case 70 vs ref 0: 0.2017
#     ✓ RMSD case 70 vs ref 1: 0.1548
#     ✓ RMSD case 70 vs ref 2: 0.1917
#     ✓ RMSD case 70 vs ref 3: 0.2139
#     ✓ RMSD case 70 vs ref 4: 0.1951
#     ✓ RMSD case 70 vs ref 5: 0.1969
#     ✓ RMSD case 70 vs ref 6: 0.2056
#     ✓ RMSD case 70 vs ref 7: 0.1760
#     ✓ RMSD case 70 vs ref 8: 0.2065
#     ✓ RMSD case 70 vs ref 9: 0.1764
#     ✓ RMSD case 70 vs ref 10: 0.2098
#     ✓ RMSD case 70 vs ref 11: 0.1926
#     ✓ RMSD case 70 vs ref 12: 0.1693
#     ✓ RMSD case 70 vs ref 13: 0.2114
#     ✓ RMSD case 70 vs ref 14: 0.2162
#     ✓ RMSD case 71 vs ref 0: 0.2131
#     ✓ RMSD case 71 vs ref 1: 0.1745
#     ✓ RMSD case 71 vs ref 2: 0.1710
#     ✓ RMSD case 71 vs ref 3: 0.1958
#     ✓ RMSD case 71 vs ref 4: 0.1587
#     ✓ RMSD case 71 vs ref 5: 0.2130
#     ✓ RMSD case 71 vs ref 6: 0.1945
#     ✓ RMSD case 71 vs ref 7: 0.1520
#     ✓ RMSD case 71 vs ref 8: 0.1893
#     ✓ RMSD case 71 vs ref 9: 0.2045
#     ✓ RMSD case 71 vs ref 10: 0.1248
#     ✓ RMSD case 71 vs ref 11: 0.2014
#     ✓ RMSD case 71 vs ref 12: 0.2083
#     ✓ RMSD case 71 vs ref 13: 0.1975
#     ✓ RMSD case 71 vs ref 14: 0.1924
#
# 📌 Performing KMeans clustering...
#
# 📌 Organizing files into cluster folders...
#   → Copied case_001.xyz to cluster_6
#   → Copied case_002.xyz to cluster_3
#   → Copied case_003.xyz to cluster_1
#   → Copied case_004.xyz to cluster_6
#   → Copied case_007.xyz to cluster_3
#   → Copied case_008.xyz to cluster_8
#   → Copied case_009.xyz to cluster_3
#   → Copied case_010.xyz to cluster_1
#   → Copied case_011.xyz to cluster_7
#   → Copied case_012.xyz to cluster_1
#   → Copied case_014.xyz to cluster_4
#   → Copied case_016.xyz to cluster_5
#   → Copied case_019.xyz to cluster_1
#   → Copied case_020.xyz to cluster_0
#   → Copied case_021.xyz to cluster_4
#   → Copied case_023.xyz to cluster_8
#   → Copied case_024.xyz to cluster_9
#   → Copied case_026.xyz to cluster_8
#   → Copied case_028.xyz to cluster_0
#   → Copied case_029.xyz to cluster_6
#   → Copied case_030.xyz to cluster_9
#   → Copied case_032.xyz to cluster_8
#   → Copied case_033.xyz to cluster_6
#   → Copied case_034.xyz to cluster_8
#   → Copied case_035.xyz to cluster_5
#   → Copied case_038.xyz to cluster_5
#   → Copied case_039.xyz to cluster_0
#   → Copied case_040.xyz to cluster_0
#   → Copied case_042.xyz to cluster_3
#   → Copied case_044.xyz to cluster_2
#   → Copied case_045.xyz to cluster_2
#   → Copied case_046.xyz to cluster_0
#   → Copied case_047.xyz to cluster_2
#   → Copied case_048.xyz to cluster_5
#   → Copied case_049.xyz to cluster_1
#   → Copied case_050.xyz to cluster_0
#   → Copied case_053.xyz to cluster_6
#   → Copied case_054.xyz to cluster_1
#   → Copied case_055.xyz to cluster_7
#   → Copied case_056.xyz to cluster_5
#   → Copied case_057.xyz to cluster_7
#   → Copied case_058.xyz to cluster_2
#   → Copied case_059.xyz to cluster_0
#   → Copied case_062.xyz to cluster_1
#   → Copied case_063.xyz to cluster_5
#   → Copied case_065.xyz to cluster_1
#   → Copied case_066.xyz to cluster_6
#   → Copied case_067.xyz to cluster_2
#   → Copied case_070.xyz to cluster_0
#   → Copied case_071.xyz to cluster_1
#   → Copied case_072.xyz to cluster_3
#   → Copied case_073.xyz to cluster_2
#   → Copied case_074.xyz to cluster_0
#   → Copied case_075.xyz to cluster_0
#   → Copied case_076.xyz to cluster_3
#   → Copied case_077.xyz to cluster_8
#   → Copied case_079.xyz to cluster_0
#   → Copied case_081.xyz to cluster_3
#   → Copied case_082.xyz to cluster_6
#   → Copied case_083.xyz to cluster_9
#   → Copied case_084.xyz to cluster_9
#   → Copied case_085.xyz to cluster_5
#   → Copied case_086.xyz to cluster_0
#   → Copied case_087.xyz to cluster_2
#   → Copied case_088.xyz to cluster_2
#   → Copied case_090.xyz to cluster_0
#   → Copied case_091.xyz to cluster_6
#   → Copied case_094.xyz to cluster_1
#   → Copied case_096.xyz to cluster_4
#   → Copied case_098.xyz to cluster_1
#   → Copied case_099.xyz to cluster_3
#   → Copied case_100.xyz to cluster_6

# %%
import os
import numpy as np
from sklearn.cluster import KMeans
from scipy.spatial import procrustes
import shutil
import pandas as pd
from scipy.spatial import ConvexHull
from sklearn.decomposition import PCA


# 설정
ref_dir = "./reference_xyz/"
case_dir = "../"
output_dir = "./clustered_cases/"
n_clusters =20

# 1. 함수 정의
def load_O_coords_from_xyz(path, start_line=15):
    with open(path, 'r') as f:
        lines = f.readlines()[start_line:]
    coords = [list(map(float, line.strip().split()[1:4])) for line in lines if line.strip().startswith('O')]
    return np.array(coords)

def rmsd(a, b):
    if a.shape != b.shape or len(a.shape) != 2:
        raise ValueError(f"Shape mismatch for RMSD: {a.shape} vs {b.shape}")
    mtx1, mtx2, _ = procrustes(a, b)
    return np.sqrt(np.mean((mtx1 - mtx2) ** 2))

def additional_features(coords):
    center = np.mean(coords, axis=0)
    dists = np.linalg.norm(coords - center, axis=1)
    mean_radius = np.mean(dists)
    std_radius = np.std(dists)

    try:
        hull = ConvexHull(coords)
        volume = hull.volume
    except:
        volume = 0.0

    pca = PCA(n_components=3)
    pca.fit(coords)
    eccentricity = pca.explained_variance_[0] / pca.explained_variance_.sum()

    return [mean_radius, std_radius, volume, eccentricity]

# 2. 참조 구조 로드
print("📌 Loading reference structures...")
reference_paths = sorted([os.path.join(ref_dir, f) for f in os.listdir(ref_dir) if f.endswith('.xyz')])
reference_structures = []
for path in reference_paths:
    coords = load_O_coords_from_xyz(path)
    reference_structures.append(coords)

# 3. 케이스 구조 로드
print("\n📌 Loading case structures...")
case_paths = sorted([os.path.join(case_dir, f) for f in os.listdir(case_dir)
                     if not os.path.isdir(os.path.join(case_dir, f)) and "ref" not in f and f.endswith('.xyz')])
case_names = [os.path.basename(p) for p in case_paths]
case_coords_list = [load_O_coords_from_xyz(p) for p in case_paths]

# 4. 확장된 특성 벡터 생성 (RMSD + 추가 지표)
print("\n📌 Computing feature vectors...")
feature_vectors = []
valid_idx = []

for i, coords in enumerate(case_coords_list):
    try:
        rmsds = [rmsd(coords, ref) for ref in reference_structures]
        features = additional_features(coords)
        feature_vectors.append(rmsds + features)
        valid_idx.append(True)
    except Exception as e:
        print(f"✗ Failed for case {case_names[i]}: {e}")
        valid_idx.append(False)

feature_vectors = np.array(feature_vectors)
filtered_case_paths = [p for i, p in enumerate(case_paths) if valid_idx[i]]
filtered_case_names = [n for i, n in enumerate(case_names) if valid_idx[i]]

# 5. KMeans 클러스터링
print("\n📌 Performing KMeans clustering...")
from sklearn.preprocessing import MinMaxScaler, StandardScaler

X_scaled = MinMaxScaler().fit_transform(feature_vectors)
X_pca = PCA(n_components=5).fit_transform(X_scaled)
labels = KMeans(n_clusters=10).fit_predict(feature_vectors)
# 6. 결과 저장
print("\n📌 Organizing files into cluster folders...")
for i in range(n_clusters):
    cluster_folder = os.path.join(output_dir, f"cluster_{i}")
    os.makedirs(cluster_folder, exist_ok=True)

for label, case_path in zip(labels, filtered_case_paths):
    shutil.copy(case_path, os.path.join(output_dir, f"cluster_{label}", os.path.basename(case_path)))
# Out:
# 📌 Loading reference structures...
#
# 📌 Loading case structures...
#
# 📌 Computing feature vectors...
#
# 📌 Performing KMeans clustering...
#
# 📌 Organizing files into cluster folders...

# %%
import matplotlib.pyplot as plt

sse = []
K_range = range(1, 60)
for k in K_range:
    km = KMeans(n_clusters=k, random_state=42)
    km.fit(X_pca)
    sse.append(km.inertia_)

plt.plot(K_range, sse, 'o-')
plt.xlabel('Number of clusters')
plt.ylabel('SSE (Inertia)')
plt.title('Elbow Method')
plt.show()
from sklearn.metrics import silhouette_score, davies_bouldin_score

sil_score = silhouette_score(feature_vectors, labels)
db_score = davies_bouldin_score(feature_vectors, labels)

print(f"Silhouette Score: {sil_score:.4f}")
print(f"Davies-Bouldin Score: {db_score:.4f}")
# Out:
# Silhouette Score: 0.5316
# Davies-Bouldin Score: 0.4331

# %%
from sklearn.metrics import silhouette_score
# 클러스터링이 얼마나 잘 되었는지를 -1 ~ 1 사이로 평가 (1에 가까울수록 좋음)
score = silhouette_score(X_pca, labels)
print(f"Silhouette Score: {score:.4f}")
# Out:
# Silhouette Score: 0.1768

# %%
# Out:
# Silhouette Score: 0.1768
# Davies-Bouldin Score: 1.2846

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
proj = pca.fit_transform(filtered_rmsd_vectors)

plt.figure(figsize=(8,6))
for i in range(n_clusters):
    idx = labels == i
    plt.scatter(proj[idx, 0], proj[idx, 1], label=f"Cluster {i}")
plt.legend()
plt.title("PCA Projection of RMSD Vectors")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, perplexity=10, random_state=42)
proj = tsne.fit_transform(filtered_rmsd_vectors)

plt.figure(figsize=(8,6))
for i in range(n_clusters):
    idx = labels == i
    plt.scatter(proj[idx, 0], proj[idx, 1], label=f"Cluster {i}")
plt.legend()
plt.title("t-SNE of RMSD Vectors")
plt.xlabel("Dim 1")
plt.ylabel("Dim 2")
plt.show()

# %%
from sklearn.cluster import DBSCAN

db = DBSCAN(eps=1.5, min_samples=5)  # eps는 거리 기준, 적절히 튜닝 필요
labels_db = db.fit_predict(filtered_rmsd_vectors)
n_clusters_db = len(set(labels_db)) - (1 if -1 in labels_db else 0)
print(f"DBSCAN found {n_clusters_db} clusters (excluding noise)")
# Out:
# DBSCAN found 1 clusters (excluding noise)

# %%
from scipy.cluster.hierarchy import linkage, dendrogram

linked = linkage(feature_vectors, method='ward')

plt.figure(figsize=(12, 6))
dendrogram(linked, labels=filtered_case_names, leaf_rotation=90)
plt.title("Hierarchical Clustering Dendrogram")
plt.show()
from scipy.cluster.hierarchy import fcluster

# 클러스터 수를 k로 지정 (예: 10개로 자르기)
k = 10
labels_hier = fcluster(linked, k, criterion='maxclust')
from sklearn.metrics import silhouette_score, davies_bouldin_score

sil_score = silhouette_score(feature_vectors, labels_hier)
db_score = davies_bouldin_score(feature_vectors, labels_hier)

print(f"Silhouette Score: {sil_score:.4f}")
print(f"Davies-Bouldin Score: {db_score:.4f}")
# Out:
# Silhouette Score: 0.5407
# Davies-Bouldin Score: 0.4386

# %%
labels_hier
# Out:
# array([ 5,  6,  7,  4, 10,  1,  2,  2,  8,  2,  6,  9,  1,  2,  2,  2,  2,
#         2,  2,  8,  9,  9,  8,  7,  3,  1,  7,  9,  1,  4,  3,  6,  1,  1,
#         2, 10,  1,  8,  7, 10,  4,  8,  1,  4,  1,  2,  4,  7,  2,  2,  4,
#         4,  7,  1,  2,  2,  6,  4,  1, 10,  8,  1, 10,  2,  2,  7, 10,  8,
#         2,  7,  1,  1], dtype=int32)

# %% [markdown]
# cases
