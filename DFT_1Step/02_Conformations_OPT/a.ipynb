# %%
import os

# %%
ALANINE_XYZ_PATH = "../01_Conformations/Alanine/"
Aminobutyric_XYZ_PATH = "../01_Conformations/Aminobutyric-acid/"
ALANINE_XYZS = [ x for x in  os.listdir(ALANINE_XYZ_PATH)  if ".xyz" in x] 
Aminobutyric_XYZS = [ x for x in  os.listdir(Aminobutyric_XYZ_PATH)  if ".xyz" in x] 

BASE_PY = "../../../00_generate_orca_input.py"
BASE_INP = "../../../00_base.inp"
for ALANINE_xyz in ALANINE_XYZS:
    path = ALANINE_XYZ_PATH + ALANINE_xyz
    out = ALANINE_xyz.replace(".xyz", ".inp")
    fd = ALANINE_xyz.replace(".xyz", "")
    os.makedirs(f"Alanine/{fd}",exist_ok=True)
    cmd = f"python {BASE_PY} {BASE_INP} {path} Alanine/{fd}/{out}"
    print(cmd)
    os.system(cmd)
for ALANINE_xyz in Aminobutyric_XYZS:
    path = Aminobutyric_XYZ_PATH + ALANINE_xyz
    out = ALANINE_xyz.replace(".xyz", ".inp")
    fd = ALANINE_xyz.replace(".xyz", "")
    os.makedirs(f"Aminobutyric/{fd}",exist_ok=True)
    cmd = f"python {BASE_PY} {BASE_INP} {path} Aminobutyric/{fd}/{out}"
    print(cmd)
    os.system(cmd)
# Out:
# python ../../../00_generate_orca_input.py ../../../00_base.inp ../01_Conformations/Alanine/00_Alanine_zwitterion.xyz Alanine/00_Alanine_zwitterion/00_Alanine_zwitterion.inp
# python ../../../00_generate_orca_input.py ../../../00_base.inp ../01_Conformations/Alanine/01_Alanine_zwitterion.xyz Alanine/01_Alanine_zwitterion/01_Alanine_zwitterion.inp
# python ../../../00_generate_orca_input.py ../../../00_base.inp ../01_Conformations/Alanine/02_Alanine_zwitterion.xyz Alanine/02_Alanine_zwitterion/02_Alanine_zwitterion.inp
# python ../../../00_generate_orca_input.py ../../../00_base.inp ../01_Conformations/Alanine/03_Alanine_zwitterion.xyz Alanine/03_Alanine_zwitterion/03_Alanine_zwitterion.inp
# python ../../../00_generate_orca_input.py ../../../00_base.inp ../01_Conformations/Aminobutyric-acid/00_Aminobutyric-acid_zwitterion.xyz Aminobutyric/00_Aminobutyric-acid_zwitterion/00_Aminobutyric-acid_zwitterion.inp
# python ../../../00_generate_orca_input.py ../../../00_base.inp ../01_Conformations/Aminobutyric-acid/01_Aminobutyric-acid_zwitterion.xyz Aminobutyric/01_Aminobutyric-acid_zwitterion/01_Aminobutyric-acid_zwitterion.inp
# python ../../../00_generate_orca_input.py ../../../00_base.inp ../01_Conformations/Aminobutyric-acid/02_Aminobutyric-acid_zwitterion.xyz Aminobutyric/02_Aminobutyric-acid_zwitterion/02_Aminobutyric-acid_zwitterion.inp
# python ../../../00_generate_orca_input.py ../../../00_base.inp ../01_Conformations/Aminobutyric-acid/03_Aminobutyric-acid_zwitterion.xyz Aminobutyric/03_Aminobutyric-acid_zwitterion/03_Aminobutyric-acid_zwitterion.inp
# python ../../../00_generate_orca_input.py ../../../00_base.inp ../01_Conformations/Aminobutyric-acid/04_Aminobutyric-acid_zwitterion.xyz Aminobutyric/04_Aminobutyric-acid_zwitterion/04_Aminobutyric-acid_zwitterion.inp
# python ../../../00_generate_orca_input.py ../../../00_base.inp ../01_Conformations/Aminobutyric-acid/05_Aminobutyric-acid_zwitterion.xyz Aminobutyric/05_Aminobutyric-acid_zwitterion/05_Aminobutyric-acid_zwitterion.inp
# python ../../../00_generate_orca_input.py ../../../00_base.inp ../01_Conformations/Aminobutyric-acid/06_Aminobutyric-acid_zwitterion.xyz Aminobutyric/06_Aminobutyric-acid_zwitterion/06_Aminobutyric-acid_zwitterion.inp
# python ../../../00_generate_orca_input.py ../../../00_base.inp ../01_Conformations/Aminobutyric-acid/07_Aminobutyric-acid_zwitterion.xyz Aminobutyric/07_Aminobutyric-acid_zwitterion/07_Aminobutyric-acid_zwitterion.inp
# python ../../../00_generate_orca_input.py ../../../00_base.inp ../01_Conformations/Aminobutyric-acid/08_Aminobutyric-acid_zwitterion.xyz Aminobutyric/08_Aminobutyric-acid_zwitterion/08_Aminobutyric-acid_zwitterion.inp

# %%
for i in  Aminobutyric_XYZS:
    path = "Aminobutyric/" + i.replace(".xyz", "")
    file = i.replace(".xyz", ".inp")
    outfile = i.replace(".xyz", ".out")
    cmd = f"cd {path} && /home/yongsang/orca_6_0_1_linux_x86-64_shared_openmpi416/orca {file} > {outfile} && cd ../../"
    print(cmd)
# Out:
# cd Aminobutyric/00_Aminobutyric-acid_zwitterion && /home/yongsang/orca_6_0_1_linux_x86-64_shared_openmpi416/orca 00_Aminobutyric-acid_zwitterion.inp > 00_Aminobutyric-acid_zwitterion.out && cd ../../
# cd Aminobutyric/01_Aminobutyric-acid_zwitterion && /home/yongsang/orca_6_0_1_linux_x86-64_shared_openmpi416/orca 01_Aminobutyric-acid_zwitterion.inp > 01_Aminobutyric-acid_zwitterion.out && cd ../../
# cd Aminobutyric/02_Aminobutyric-acid_zwitterion && /home/yongsang/orca_6_0_1_linux_x86-64_shared_openmpi416/orca 02_Aminobutyric-acid_zwitterion.inp > 02_Aminobutyric-acid_zwitterion.out && cd ../../
# cd Aminobutyric/03_Aminobutyric-acid_zwitterion && /home/yongsang/orca_6_0_1_linux_x86-64_shared_openmpi416/orca 03_Aminobutyric-acid_zwitterion.inp > 03_Aminobutyric-acid_zwitterion.out && cd ../../
# cd Aminobutyric/04_Aminobutyric-acid_zwitterion && /home/yongsang/orca_6_0_1_linux_x86-64_shared_openmpi416/orca 04_Aminobutyric-acid_zwitterion.inp > 04_Aminobutyric-acid_zwitterion.out && cd ../../
# cd Aminobutyric/05_Aminobutyric-acid_zwitterion && /home/yongsang/orca_6_0_1_linux_x86-64_shared_openmpi416/orca 05_Aminobutyric-acid_zwitterion.inp > 05_Aminobutyric-acid_zwitterion.out && cd ../../
# cd Aminobutyric/06_Aminobutyric-acid_zwitterion && /home/yongsang/orca_6_0_1_linux_x86-64_shared_openmpi416/orca 06_Aminobutyric-acid_zwitterion.inp > 06_Aminobutyric-acid_zwitterion.out && cd ../../
# cd Aminobutyric/07_Aminobutyric-acid_zwitterion && /home/yongsang/orca_6_0_1_linux_x86-64_shared_openmpi416/orca 07_Aminobutyric-acid_zwitterion.inp > 07_Aminobutyric-acid_zwitterion.out && cd ../../
# cd Aminobutyric/08_Aminobutyric-acid_zwitterion && /home/yongsang/orca_6_0_1_linux_x86-64_shared_openmpi416/orca 08_Aminobutyric-acid_zwitterion.inp > 08_Aminobutyric-acid_zwitterion.out && cd ../../

# %%
for i in  ALANINE_XYZS:
    path = "Alanine/" + i.replace(".xyz", "")
    file = i.replace(".xyz", ".inp")
    outfile = i.replace(".xyz", ".out")
    cmd = f"cd {path} && /home/yongsang/orca_6_0_1_linux_x86-64_shared_openmpi416/orca {file} > {outfile} && cd ../../"
    print(cmd)
# Out:
# cd Alanine/00_Alanine_zwitterion && /home/yongsang/orca_6_0_1_linux_x86-64_shared_openmpi416/orca 00_Alanine_zwitterion.inp > 00_Alanine_zwitterion.out && cd ../../
# cd Alanine/01_Alanine_zwitterion && /home/yongsang/orca_6_0_1_linux_x86-64_shared_openmpi416/orca 01_Alanine_zwitterion.inp > 01_Alanine_zwitterion.out && cd ../../
# cd Alanine/02_Alanine_zwitterion && /home/yongsang/orca_6_0_1_linux_x86-64_shared_openmpi416/orca 02_Alanine_zwitterion.inp > 02_Alanine_zwitterion.out && cd ../../
# cd Alanine/03_Alanine_zwitterion && /home/yongsang/orca_6_0_1_linux_x86-64_shared_openmpi416/orca 03_Alanine_zwitterion.inp > 03_Alanine_zwitterion.out && cd ../../

# %%
import pandas as pd 
import matplotlib.pyplot as plt 

# 데이터 불러오기
df = pd.read_excel("./Alanine_Conformations.xlsx")

# 막대 그래프 그리기
plt.figure(figsize=(10, 6))
bars = plt.bar(["Alanine " + str(x) for x in df["Index"]], df["FinalSinglePointEnergy"])

# 자동 ylim + 여유 공간 조정
ymin = df["FinalSinglePointEnergy"].min()
ymax = df["FinalSinglePointEnergy"].max()
yrange = ymax - ymin
plt.ylim(ymin - 0.2 * yrange, ymax + 0.3 * yrange)  # 여유 공간 10%

# 시각적 요소
plt.ylabel("Final Single Point Energy (Eh)")
plt.title("Alanine Conformations: Final Single Point Energies")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.savefig("./Alanine_Conformations.png")
plt.show()

# %%
import pandas as pd 
import matplotlib.pyplot as plt 

# 데이터 불러오기
df = pd.read_excel("./Aminobutyric_Conformations.xlsx")

# 막대 그래프 그리기
plt.figure(figsize=(10, 6))
bars = plt.bar(["Aminobutyric " + str(x) for x in df["Index"]], df["FinalSinglePointEnergy"])

# 자동 ylim + 여유 공간 조정
ymin = df["FinalSinglePointEnergy"].min()
ymax = df["FinalSinglePointEnergy"].max()
yrange = ymax - ymin
plt.ylim(ymin - 0.2 * yrange, ymax + 0.3 * yrange)  # 여유 공간 10%

# 시각적 요소
plt.ylabel("Final Single Point Energy (Eh)")
plt.title("Aminobutyric Conformations: Final Single Point Energies")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.savefig("./Aminobutyric_Conformations.png")
plt.show()

# %%
df
# Out:
#    Index  FinalSinglePointEnergy
# 0      0             -323.737871
# 1      1             -323.747206
# 2      2             -323.747192
# 3      3             -323.737886
